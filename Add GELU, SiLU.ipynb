# %% [markdown]
# <a href="https://colab.research.google.com/github/cjfghk5697/AjouDeeplearning_Compete/blob/main/Add%20GELU%2C%20SiLU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. 이진화 코드 추가
#  이진화란 이미지를 흰색과 검은색으로 바꾼다고 생각하면 된다.
# 속도가 향상되고 정확도도 미약하지만 향상된것을 볼수 있다.
#
#  [Dacon 적용 예시](https://dacon.io/competitions/official/235697/codeshare/2436?page=2&dtype=recent)
#
#
#  [이진화 설명](https://gmnam.tistory.com/263)
#
#  <hr>
#
#  # 2. train, valid set 나누기
# ```
# train_dataset, valid_dataset = torch.utils.data.random_split(trainset, [train_size, valid_size])
#
# train_loader = DataLoader(train_dataset, batch_size=64, num_workers=8)
# valid_loader = DataLoader(valid_dataset, batch_size=64, num_workers=8)
# ```
# 처음에는 나누어지지 않아있는 코드였단 걸 발견하고 random_split 함수를 이용해 나눔. 그리고 학습 부분에서 valid 데이터를 enumerate하는 구문추가해서 valid 확인.
#
# <hr>
#
# # 3. Multi Sample Dropout 구현
#
# [자료](https://velog.io/@sujeongim/%EC%83%88%EB%A1%9C-%EB%B0%B0%EC%9A%B4-%EC%BD%94%EB%93%9C-%EC%A1%B0%EA%B0%81-Multi-Sample-Dropout)
# 단순 dropout 기법을 안썼다. 근데 큰효과가 있는지는 잘 모르지만 overfitting의 위협도 없앨겸 선택했다.
#
# <hr>
#
# # 4. Scheduler 추가
# 일단 간단하게 StepLR scheduler을 추가했다.
#
#
#
# <hr>
#
# # 5. Drop out 실수
# 전 Drop out에서는 sigmoid가 있다. 근데 필자가 Multi-Label Loss Function을 이용함으로써 활성화 함수를 더 추가할 필요가 없었다. 그러나 sigmoid를 또 넣음으로써 sigmoid 계층 2개를 들어가는 거다. 결국 loss 값이 적어져서 학습 진행이 안된거다. 학습이 잘 안되면 활성화 함수에서 loss 값이 얼마 나오는지 잘 확인해야겠다..
#
# https://cvml.tistory.com/26
# Multi-Label Loss Function에 대해 잘 설명 되어있다.
#
#
# <hr>
#
# # 6. 왜 정확도가 안오를까?
# 이상하게도 valid도 장확도가 같이 오르는데 test를 하면 정확도는 50%다 혹시나 해서 이진화를 빼고 해봤는데도 정확도가 안오른다 (05.15)
#
# -테스트
#
# 1. efficientnetb1에서 epoch 수를 늘려봤다. 과거에는 5번 정도만 해도 valid 정확도가 높게 나왔다. 하지만 epoch를 늘린다고 해결될 일이 절대 아닌 거 같다.
#
# 2. overfitting 인거 같아서 dropout을 추가했다. 활성화 함수도 한층 추가해봐서 실험. (실패)
#
# 3. 추적그래프를 그리기 위해 추적그래프를 추가했다.
#
# 4. DACON 토론에 올렸다.[링크](https://dacon.io/forum/406352)  답변이 왔고 확실히 여기서 model.eval()과 model.train(), model.zero_grab()에 대해 다시 공부했다.. valid에 zero_grab을 하여 학습이 진행되고 있었고 eval 또한 안해서 불필요한 과정을 가지고 있었다.
#
# ### 해결
# 결국은 inference에서 모델을 잘못 가지고 오고 있었다.. 결국 다시해본결과 80% 정확도가 나왔지만 아직 90% 정확도는 안나온다.
#
# # 7. 또다시 연구
# 이번에는 적절한 파라미터를 찾기위한 튜닝 작업을 해보고자 한다.
#
# 일단 Train 코드에서는 augmentation(mix up
# )과 여러 scheduler를 추가하려고한다. 이제 휴가가 끝나서 시간 날때마다 추가해야겠다.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Train image2
# !unzip -q "/content/drive/MyDrive/multi-mnist zipfile/dirty_mnist_2nd.zip"
# Out:
# /content/drive/MyDrive/Train image2

# %%
# !pip3 install torchinfo
# !pip3 install cv2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchinfo
#   Downloading torchinfo-1.7.0-py3-none-any.whl (22 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.7.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement cv2 (from versions: none)
# ERROR: No matching distribution found for cv2

# %%
import os
from typing import Tuple, Sequence, Callable
import csv
import cv2
import numpy as np
import pandas as pd
from PIL import Image
import torch
import torch.optim as optim
from torch import nn, Tensor
from torch.utils.data import Dataset, DataLoader
from torchinfo import summary
from torchvision import transforms
from torchvision.models import efficientnet_b3
from torch.nn import functional as F
from torch.autograd import Variable

# %%
class MnistDataset(Dataset):
    def __init__(
        self,
        dir: os.PathLike,
        image_ids: os.PathLike,
        transforms: Sequence[Callable]
    ) -> None:
        self.dir = dir
        self.transforms = transforms

        self.labels = {}
        with open(image_ids, 'r') as f:
            reader = csv.reader(f)
            next(reader)
            for row in reader:
                self.labels[int(row[0])] = list(map(int, row[1:]))

        self.image_ids = list(self.labels.keys())

    def __len__(self) -> int:
        return len(self.image_ids)

    def __getitem__(self, index: int) -> Tuple[Tensor]:
        image_id = self.image_ids[index]
        image = Image.open(
            os.path.join(
                self.dir, f'{str(image_id).zfill(5)}.png')).convert('RGB')
        target = np.array(self.labels.get(image_id)).astype(np.float32)


        #image = np.array(image)
#이진화 완료 cv2 툴을 써서 threshold로 254 값으로 변환. cv2는 넘파이만 사용 가능해서 넘파이로 변환후 fromarry로 pil로 바꾼다.
        #image_th = cv2.threshold(image,254,255,0)[1]
        #image_th = Image.fromarray(image_th) # NumPy array to PIL image
        if self.transforms is not None:
            image = self.transforms(image)

        return image, target

# %%
transforms_train = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(p=0.5),
    transforms.ToTensor(),
    transforms.Normalize(
        [0.485, 0.456, 0.406],
        [0.229, 0.224, 0.225]
    )
])

transforms_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(
        [0.485, 0.456, 0.406],
        [0.229, 0.224, 0.225]
    )
])

# %%
trainset = MnistDataset('/content/drive/MyDrive/Train image2', '/content/drive/MyDrive/multi-mnist zipfile/dirty_mnist_2nd_answer.csv', transforms_train)

lengths = [int(len(trainset)*0.8), int(len(trainset)*0.2)]

train_dataset, valid_dataset = torch.utils.data.random_split(trainset, lengths)

train_loader = DataLoader(train_dataset, batch_size=16, num_workers=2)
valid_loader = DataLoader(valid_dataset, batch_size=8, num_workers=2)

# %%
class MnistModel(nn.Module):
    def __init__(self) -> None:
        super().__init__()
        self.model = efficientnet_b3(pretrained=True)
        self.dropout=nn.Dropout(p=0.2)
        self.classifier = nn.Linear(1000, 26)
        self.SiLU=nn.SiLU(inplace=False)
        self.GELU=nn.GELU()
    def forward(self, x):
        #x = F.relu(self.model(x))
        x = self.model(x) 
        x = self.dropout(x)
        x = self.GELU(x) 
        x = self.classifier(x)
        return x

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = MnistModel().to(device)
print(summary(model, input_size=(1, 3, 256, 256), verbose=0))
# Out:
# ==============================================================================================================
# Layer (type:depth-idx)                                       Output Shape              Param #
# ==============================================================================================================
# MnistModel                                                   [1, 26]                   --
# ├─EfficientNet: 1-1                                          [1, 1000]                 --
# │    └─Sequential: 2-1                                       [1, 1536, 8, 8]           --
# │    │    └─ConvNormActivation: 3-1                          [1, 40, 128, 128]         1,160
# │    │    └─Sequential: 3-2                                  [1, 24, 128, 128]         3,504
# │    │    └─Sequential: 3-3                                  [1, 32, 64, 64]           48,118
# │    │    └─Sequential: 3-4                                  [1, 48, 32, 32]           110,912
# │    │    └─Sequential: 3-5                                  [1, 96, 16, 16]           638,700
# │    │    └─Sequential: 3-6                                  [1, 136, 16, 16]          1,387,760
# │    │    └─Sequential: 3-7                                  [1, 232, 8, 8]            4,628,964
# │    │    └─Sequential: 3-8                                  [1, 384, 8, 8]            3,284,218
# │    │    └─ConvNormActivation: 3-9                          [1, 1536, 8, 8]           592,896
# │    └─AdaptiveAvgPool2d: 2-2                                [1, 1536, 1, 1]           --
# │    └─Sequential: 2-3                                       [1, 1000]                 --
# │    │    └─Dropout: 3-10                                    [1, 1536]                 --
# │    │    └─Linear: 3-11                                     [1, 1000]                 1,537,000
# ├─Dropout: 1-2                                               [1, 1000]                 --
# ├─GELU: 1-3                                                  [1, 1000]                 --
# ├─Linear: 1-4                                                [1, 26]                   26,026
# ==============================================================================================================
# Total params: 12,259,258
# Trainable params: 12,259,258
# Non-trainable params: 0
# Total mult-adds (G): 1.26
# ==============================================================================================================
# Input size (MB): 0.79
# Forward/backward pass size (MB): 271.55
# Params size (MB): 49.04
# Estimated Total Size (MB): 321.38
# ==============================================================================================================

# %%
def mixup_data(x, y, alpha=1.0, use_cuda=True):
    '''Returns mixed inputs, pairs of targets, and lambda'''
    if alpha > 0:
        lam = np.random.beta(alpha, alpha)
    else:
        lam = 1

    batch_size = x.size()[0]
    if use_cuda:
        index = torch.randperm(batch_size).cuda()
    else:
        index = torch.randperm(batch_size)

    mixed_x = lam * x + (1 - lam) * x[index, :]
    y_a, y_b = y, y[index]
    return mixed_x, y_a, y_b, lam


def mixup_criterion(criterion, pred, y_a, y_b, lam):
    return lam * criterion(pred, y_a) + (1 - lam) * criterion(pred, y_b)

# %%
    #scheduler 추가 및 step 추가
path = "/content/drive/MyDrive/models/"
MODEL = "06012 eff3"
base_optimizer = torch.optim.SGD 
optimizer = optim.AdamW(model.parameters(), lr=1e-3)

num_epochs = 50
lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=10, T_mult=1, eta_min=0.001, last_epoch=-1)
criterion = nn.MultiLabelSoftMarginLoss()

valid_loss_list=[]
train_loss_list=[]
for epoch in range(num_epochs):
    train_acc_list = []
    valid_acc_list =[]
    model.train()
    for i, (images, targets) in enumerate(train_loader):
        optimizer.zero_grad()

        images = images.to(device)
        targets = targets.to(device)

        images, targets_a, targets_b, lam = mixup_data(images, targets)
        images, targets_a, targets_b = map(Variable, (images, targets_a, targets_b))

        outputs = model(images)
        loss = mixup_criterion(criterion, outputs, targets_a, targets_b, lam)

        loss.backward()
        optimizer.step()

        if (i+1) % 10 == 0:
            outputs = outputs > 0.5
            acc = (outputs == targets).cpu().float().mean()
            train_acc_list.append(acc)
            train_loss_list.append(loss)
            print(f'{epoch}: "train loss:"{loss.item():.5f}, "train acc: "{acc.item():.5f}')
    model.eval()
    with torch.no_grad():
      for i, (images, targets) in enumerate(valid_loader):

          images = images.to(device)
          targets = targets.to(device)

          outputs = model(images)
          valid_loss = criterion(outputs, targets)
      
          if (i+1) % 10 == 0:
              outputs = outputs > 0.5
              valid_acc = (outputs == targets).cpu().float().mean()
              valid_acc_list.append(valid_acc)
              valid_loss_list.append(valid_loss)
              print(f'{epoch}: "val loss:"{valid_loss.item():.5f}, "val acc: "{valid_acc.item():.5f}')
    lr_scheduler.step()
    torch.save(model.state_dict(), f'{path}_{MODEL}_1.pth')
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 0: "train loss:"0.69115, "train acc: "0.53125
# 0: "train loss:"0.69066, "train acc: "0.51923
# 0: "train loss:"0.69837, "train acc: "0.50962
# 0: "train loss:"0.68855, "train acc: "0.53606
# 0: "train loss:"0.68318, "train acc: "0.55529
# 0: "train loss:"0.68831, "train acc: "0.55529
# 0: "train loss:"0.68953, "train acc: "0.54327
# 0: "train loss:"0.68990, "train acc: "0.53606
# 0: "train loss:"0.68713, "train acc: "0.55288
# 0: "train loss:"0.68786, "train acc: "0.54808
# 0: "train loss:"0.69115, "train acc: "0.51202
# 0: "train loss:"0.69083, "train acc: "0.52885
# 0: "train loss:"0.69115, "train acc: "0.54327
# 0: "train loss:"0.69583, "train acc: "0.51923
# 0: "train loss:"0.68551, "train acc: "0.55288
# 0: "train loss:"0.69026, "train acc: "0.54087
# 0: "train loss:"0.68567, "train acc: "0.55288
# 0: "train loss:"0.68771, "train acc: "0.54327
# 0: "train loss:"0.68313, "train acc: "0.55529
# 0: "train loss:"0.68554, "train acc: "0.55769
# 0: "train loss:"0.69116, "train acc: "0.53606
# 0: "train loss:"0.68649, "train acc: "0.54808
# 0: "train loss:"0.68903, "train acc: "0.54087
# 0: "train loss:"0.69218, "train acc: "0.52163
# 0: "train loss:"0.68661, "train acc: "0.53606
# 0: "train loss:"0.68767, "train acc: "0.54567
# 0: "train loss:"0.69007, "train acc: "0.52885
# 0: "train loss:"0.68679, "train acc: "0.54327
# 0: "train loss:"0.68768, "train acc: "0.54087
# 0: "train loss:"0.69263, "train acc: "0.52644
# 0: "train loss:"0.68929, "train acc: "0.54808
# 0: "train loss:"0.68518, "train acc: "0.56250
# 0: "train loss:"0.69060, "train acc: "0.53125
# 0: "train loss:"0.68856, "train acc: "0.54327
# 0: "train loss:"0.68611, "train acc: "0.53125
# 0: "train loss:"0.68750, "train acc: "0.55288
# 0: "train loss:"0.69231, "train acc: "0.52404
# 0: "train loss:"0.69108, "train acc: "0.53846
# 0: "train loss:"0.68813, "train acc: "0.53846
# 0: "train loss:"0.68395, "train acc: "0.57452
# 0: "train loss:"0.69578, "train acc: "0.51202
# 0: "train loss:"0.69081, "train acc: "0.52404
# 0: "train loss:"0.68733, "train acc: "0.53846
# 0: "train loss:"0.69013, "train acc: "0.52404
# 0: "train loss:"0.68724, "train acc: "0.54087
# 0: "train loss:"0.68817, "train acc: "0.54087
# 0: "train loss:"0.68622, "train acc: "0.53606
# 0: "train loss:"0.69199, "train acc: "0.53606
# 0: "train loss:"0.69031, "train acc: "0.53365
# 0: "train loss:"0.68576, "train acc: "0.55048
# 0: "train loss:"0.68995, "train acc: "0.54087
# 0: "train loss:"0.68500, "train acc: "0.54567
# 0: "train loss:"0.68522, "train acc: "0.55288
# 0: "train loss:"0.69085, "train acc: "0.52163
# 0: "train loss:"0.69055, "train acc: "0.53125
# 0: "train loss:"0.69211, "train acc: "0.53846
# 0: "train loss:"0.69278, "train acc: "0.52404
# 0: "train loss:"0.69374, "train acc: "0.51442
# 0: "train loss:"0.68516, "train acc: "0.55048
# 0: "train loss:"0.68827, "train acc: "0.53846
# 0: "train loss:"0.68927, "train acc: "0.54327
# 0: "train loss:"0.68330, "train acc: "0.53365
# 0: "train loss:"0.68893, "train acc: "0.53606
# 0: "train loss:"0.68240, "train acc: "0.54567
# 0: "train loss:"0.68395, "train acc: "0.54567
# 0: "train loss:"0.68806, "train acc: "0.52644
# 0: "train loss:"0.68259, "train acc: "0.55769
# 0: "train loss:"0.68450, "train acc: "0.54567
# 0: "train loss:"0.68745, "train acc: "0.55048
# 0: "train loss:"0.69008, "train acc: "0.52404
# 0: "train loss:"0.69379, "train acc: "0.50721
# 0: "train loss:"0.68893, "train acc: "0.54327
# 0: "train loss:"0.68561, "train acc: "0.56731
# 0: "train loss:"0.68786, "train acc: "0.55288
# 0: "train loss:"0.68812, "train acc: "0.52644
# 0: "train loss:"0.68886, "train acc: "0.53846
# 0: "train loss:"0.68999, "train acc: "0.53125
# 0: "train loss:"0.68193, "train acc: "0.54327
# 0: "train loss:"0.68847, "train acc: "0.53846
# 0: "train loss:"0.68530, "train acc: "0.54567
# 0: "train loss:"0.69145, "train acc: "0.53846
# 0: "train loss:"0.68941, "train acc: "0.54327
# 0: "train loss:"0.69366, "train acc: "0.51442
# 0: "train loss:"0.68643, "train acc: "0.53846
# 0: "train loss:"0.68739, "train acc: "0.54327
# 0: "train loss:"0.68721, "train acc: "0.53365
# 0: "train loss:"0.68480, "train acc: "0.55288
# 0: "train loss:"0.68974, "train acc: "0.51923
# 0: "train loss:"0.68508, "train acc: "0.56971
# 0: "train loss:"0.68599, "train acc: "0.56010
# 0: "train loss:"0.68788, "train acc: "0.52885
# 0: "train loss:"0.69027, "train acc: "0.53846
# 0: "train loss:"0.69186, "train acc: "0.53365
# 0: "train loss:"0.68846, "train acc: "0.55288
# 0: "train loss:"0.68745, "train acc: "0.54327
# 0: "train loss:"0.68827, "train acc: "0.54567
# 0: "train loss:"0.68409, "train acc: "0.55769
# 0: "train loss:"0.68851, "train acc: "0.54087
# 0: "train loss:"0.69175, "train acc: "0.53125
# 0: "train loss:"0.68936, "train acc: "0.53606
# 0: "train loss:"0.68448, "train acc: "0.54087
# 0: "train loss:"0.69439, "train acc: "0.50721
# 0: "train loss:"0.68743, "train acc: "0.53606
# 0: "train loss:"0.68418, "train acc: "0.55529
# 0: "train loss:"0.69191, "train acc: "0.56010
# 0: "train loss:"0.68490, "train acc: "0.56010
# 0: "train loss:"0.68925, "train acc: "0.53606
# 0: "train loss:"0.68354, "train acc: "0.54087
# 0: "train loss:"0.69348, "train acc: "0.50000
# 0: "train loss:"0.68588, "train acc: "0.53606
# 0: "train loss:"0.67743, "train acc: "0.54327
# 0: "train loss:"0.68899, "train acc: "0.53846
# 0: "train loss:"0.69222, "train acc: "0.52644
# 0: "train loss:"0.68980, "train acc: "0.51442
# 0: "train loss:"0.68971, "train acc: "0.52404
# 0: "train loss:"0.68944, "train acc: "0.53606
# 0: "train loss:"0.68947, "train acc: "0.54327
# 0: "train loss:"0.68309, "train acc: "0.52163
# 0: "train loss:"0.68589, "train acc: "0.55529
# 0: "train loss:"0.68657, "train acc: "0.54808
# 0: "train loss:"0.68634, "train acc: "0.54087
# 0: "train loss:"0.69618, "train acc: "0.51442
# 0: "train loss:"0.68547, "train acc: "0.53365
# 0: "train loss:"0.68754, "train acc: "0.53846
# 0: "train loss:"0.68564, "train acc: "0.53365
# 0: "train loss:"0.69120, "train acc: "0.54087
# 0: "train loss:"0.68793, "train acc: "0.54087
# 0: "train loss:"0.68798, "train acc: "0.55529
# 0: "train loss:"0.68390, "train acc: "0.52163
# 0: "train loss:"0.68598, "train acc: "0.51202
# 0: "train loss:"0.68648, "train acc: "0.52163
# 0: "train loss:"0.67939, "train acc: "0.51923
# 0: "train loss:"0.68358, "train acc: "0.54808
# 0: "train loss:"0.68815, "train acc: "0.50240
# 0: "train loss:"0.68353, "train acc: "0.53125
# 0: "train loss:"0.68739, "train acc: "0.54808
# 0: "train loss:"0.69472, "train acc: "0.51442
# 0: "train loss:"0.67664, "train acc: "0.56010
# 0: "train loss:"0.68723, "train acc: "0.54087
# 0: "train loss:"0.69739, "train acc: "0.53606
# 0: "train loss:"0.67909, "train acc: "0.55769
# 0: "train loss:"0.68419, "train acc: "0.53125
# 0: "train loss:"0.68620, "train acc: "0.55048
# 0: "train loss:"0.68595, "train acc: "0.53365
# 0: "train loss:"0.68647, "train acc: "0.52885
# 0: "train loss:"0.68524, "train acc: "0.52404
# 0: "train loss:"0.68293, "train acc: "0.53125
# 0: "train loss:"0.68560, "train acc: "0.55288
# 0: "train loss:"0.68413, "train acc: "0.55048
# 0: "train loss:"0.68740, "train acc: "0.54567
# 0: "train loss:"0.68343, "train acc: "0.50721
# 0: "train loss:"0.68735, "train acc: "0.51442
# 0: "train loss:"0.68681, "train acc: "0.56250
# 0: "train loss:"0.69058, "train acc: "0.54808
# 0: "train loss:"0.68038, "train acc: "0.55048
# 0: "train loss:"0.68184, "train acc: "0.54567
# 0: "train loss:"0.69125, "train acc: "0.52885
# 0: "train loss:"0.68598, "train acc: "0.55769
# 0: "train loss:"0.69640, "train acc: "0.50240
# 0: "train loss:"0.68580, "train acc: "0.55529
# 0: "train loss:"0.68768, "train acc: "0.54087
# 0: "train loss:"0.68472, "train acc: "0.56250
# 0: "train loss:"0.68547, "train acc: "0.54327
# 0: "train loss:"0.68614, "train acc: "0.54087
# 0: "train loss:"0.68379, "train acc: "0.56250
# 0: "train loss:"0.69608, "train acc: "0.52163
# 0: "train loss:"0.68685, "train acc: "0.52644
# 0: "train loss:"0.68657, "train acc: "0.54567
# 0: "train loss:"0.68221, "train acc: "0.52163
# 0: "train loss:"0.68108, "train acc: "0.51202
# 0: "train loss:"0.67982, "train acc: "0.54567
# 0: "train loss:"0.69432, "train acc: "0.52644
# 0: "train loss:"0.68353, "train acc: "0.53606
# 0: "train loss:"0.68491, "train acc: "0.53606
# 0: "train loss:"0.69417, "train acc: "0.52885
# 0: "train loss:"0.68048, "train acc: "0.53365
# 0: "train loss:"0.69049, "train acc: "0.54808
# 0: "train loss:"0.68094, "train acc: "0.55048
# 0: "train loss:"0.69058, "train acc: "0.54087
# 0: "train loss:"0.68669, "train acc: "0.55288
# 0: "train loss:"0.68476, "train acc: "0.54567
# 0: "train loss:"0.68771, "train acc: "0.53365
# 0: "train loss:"0.68180, "train acc: "0.53125
# 0: "train loss:"0.69044, "train acc: "0.54087
# 0: "val loss:"0.70374, "val acc: "0.53365
# 0: "val loss:"0.70430, "val acc: "0.53365
# 0: "val loss:"0.71336, "val acc: "0.50481
# 0: "val loss:"0.68810, "val acc: "0.52885
# 0: "val loss:"0.68567, "val acc: "0.57692
# 0: "val loss:"0.69642, "val acc: "0.52404
# 0: "val loss:"0.67310, "val acc: "0.56250
# 0: "val loss:"0.70995, "val acc: "0.51442
# 0: "val loss:"0.69628, "val acc: "0.55288
# 0: "val loss:"0.66953, "val acc: "0.55769
# 0: "val loss:"0.69434, "val acc: "0.53846
# 0: "val loss:"0.69082, "val acc: "0.50962
# 0: "val loss:"0.68085, "val acc: "0.56250
# 0: "val loss:"0.69014, "val acc: "0.56731
# 0: "val loss:"0.68352, "val acc: "0.52404
# 0: "val loss:"0.70458, "val acc: "0.54327
# 0: "val loss:"0.68695, "val acc: "0.57692
# 0: "val loss:"0.69492, "val acc: "0.58173
# 0: "val loss:"0.70540, "val acc: "0.51923
# 0: "val loss:"0.70822, "val acc: "0.52404
# 0: "val loss:"0.69440, "val acc: "0.53365
# 0: "val loss:"0.69260, "val acc: "0.55769
# 0: "val loss:"0.68694, "val acc: "0.52885
# 0: "val loss:"0.70173, "val acc: "0.52885
# 0: "val loss:"0.69239, "val acc: "0.53365
# 0: "val loss:"0.70410, "val acc: "0.53365
# 0: "val loss:"0.68106, "val acc: "0.55769
# 0: "val loss:"0.68942, "val acc: "0.53846
# 0: "val loss:"0.68083, "val acc: "0.58173
# 0: "val loss:"0.68731, "val acc: "0.53846
# 0: "val loss:"0.70197, "val acc: "0.54327
# 0: "val loss:"0.70936, "val acc: "0.55769
# 0: "val loss:"0.70017, "val acc: "0.56250
# 0: "val loss:"0.68433, "val acc: "0.55288
# 0: "val loss:"0.68813, "val acc: "0.55288
# 0: "val loss:"0.68638, "val acc: "0.54808
# 0: "val loss:"0.67178, "val acc: "0.60096
# 0: "val loss:"0.68044, "val acc: "0.58173
# 0: "val loss:"0.69561, "val acc: "0.54327
# 0: "val loss:"0.70662, "val acc: "0.54327
# 0: "val loss:"0.70940, "val acc: "0.52404
# 0: "val loss:"0.68393, "val acc: "0.54327
# 0: "val loss:"0.69829, "val acc: "0.53365
# 0: "val loss:"0.68233, "val acc: "0.55769
# 0: "val loss:"0.68595, "val acc: "0.55769
# 0: "val loss:"0.69611, "val acc: "0.51442
# 0: "val loss:"0.70470, "val acc: "0.51442
# 0: "val loss:"0.69868, "val acc: "0.54808
# 0: "val loss:"0.71995, "val acc: "0.50481
# 0: "val loss:"0.68575, "val acc: "0.55769
# 0: "val loss:"0.67860, "val acc: "0.57212
# 0: "val loss:"0.71691, "val acc: "0.52404
# 0: "val loss:"0.69457, "val acc: "0.51923
# 0: "val loss:"0.69564, "val acc: "0.50962
# 0: "val loss:"0.70693, "val acc: "0.55769
# 0: "val loss:"0.67700, "val acc: "0.57212
# 0: "val loss:"0.69363, "val acc: "0.54327
# 0: "val loss:"0.69836, "val acc: "0.52885
# 0: "val loss:"0.70516, "val acc: "0.52404
# 0: "val loss:"0.69181, "val acc: "0.54327
# 0: "val loss:"0.68560, "val acc: "0.55769
# 0: "val loss:"0.66560, "val acc: "0.56250
# 0: "val loss:"0.70281, "val acc: "0.54327
# 0: "val loss:"0.71536, "val acc: "0.55288
# 0: "val loss:"0.69882, "val acc: "0.53846
# 0: "val loss:"0.70147, "val acc: "0.55769
# 0: "val loss:"0.70304, "val acc: "0.53846
# 0: "val loss:"0.68284, "val acc: "0.56250
# 0: "val loss:"0.68196, "val acc: "0.54327
# 0: "val loss:"0.69081, "val acc: "0.52404
# 0: "val loss:"0.69453, "val acc: "0.55288
# 0: "val loss:"0.70942, "val acc: "0.54808
# 0: "val loss:"0.68894, "val acc: "0.56731
# 0: "val loss:"0.68476, "val acc: "0.57692
# 0: "val loss:"0.71074, "val acc: "0.52404
# 0: "val loss:"0.68858, "val acc: "0.52885
# 0: "val loss:"0.67744, "val acc: "0.58654
# 0: "val loss:"0.69239, "val acc: "0.56250
# 0: "val loss:"0.68737, "val acc: "0.53365
# 0: "val loss:"0.67377, "val acc: "0.58173
# 0: "val loss:"0.69016, "val acc: "0.52404
# 0: "val loss:"0.68142, "val acc: "0.55288
# 0: "val loss:"0.68039, "val acc: "0.56250
# 0: "val loss:"0.68670, "val acc: "0.53365
# 0: "val loss:"0.68326, "val acc: "0.58173
# 0: "val loss:"0.68799, "val acc: "0.54808
# 0: "val loss:"0.71020, "val acc: "0.52885
# 0: "val loss:"0.67104, "val acc: "0.59615
# 0: "val loss:"0.69281, "val acc: "0.55288
# 0: "val loss:"0.68113, "val acc: "0.54327
# 0: "val loss:"0.69993, "val acc: "0.53365
# 0: "val loss:"0.70562, "val acc: "0.51923
# 0: "val loss:"0.66292, "val acc: "0.55769
# 0: "val loss:"0.69495, "val acc: "0.55769
# 0: "val loss:"0.70021, "val acc: "0.53365
# 0: "val loss:"0.69083, "val acc: "0.57212
# 0: "val loss:"0.70380, "val acc: "0.50962
# 0: "val loss:"0.68428, "val acc: "0.53846
# 0: "val loss:"0.65925, "val acc: "0.57212
# 0: "val loss:"0.68418, "val acc: "0.54327
# 0: "val loss:"0.68821, "val acc: "0.56731
# 0: "val loss:"0.70705, "val acc: "0.53846
# 0: "val loss:"0.68468, "val acc: "0.59135
# 0: "val loss:"0.69157, "val acc: "0.54327
# 0: "val loss:"0.69681, "val acc: "0.53365
# 0: "val loss:"0.70438, "val acc: "0.52885
# 0: "val loss:"0.69043, "val acc: "0.54808
# 0: "val loss:"0.69041, "val acc: "0.55288
# 0: "val loss:"0.71218, "val acc: "0.53365
# 0: "val loss:"0.67619, "val acc: "0.54327
# 0: "val loss:"0.70142, "val acc: "0.55288
# 0: "val loss:"0.69847, "val acc: "0.53846
# 0: "val loss:"0.69786, "val acc: "0.56250
# 0: "val loss:"0.71034, "val acc: "0.50962
# 0: "val loss:"0.68961, "val acc: "0.53365
# 0: "val loss:"0.67766, "val acc: "0.54327
# 0: "val loss:"0.69396, "val acc: "0.58173
# 0: "val loss:"0.71280, "val acc: "0.50481
# 0: "val loss:"0.70510, "val acc: "0.53846
# 0: "val loss:"0.69855, "val acc: "0.55769
# 0: "val loss:"0.70857, "val acc: "0.52885
# 0: "val loss:"0.70346, "val acc: "0.55769
# 0: "val loss:"0.66866, "val acc: "0.58654
# 0: "val loss:"0.69939, "val acc: "0.53846
# 0: "val loss:"0.68995, "val acc: "0.53846
# 1: "train loss:"0.69342, "train acc: "0.53365
# 1: "train loss:"0.69108, "train acc: "0.53606
# 1: "train loss:"0.68467, "train acc: "0.54327
# 1: "train loss:"0.68515, "train acc: "0.54567
# 1: "train loss:"0.68989, "train acc: "0.52644
# 1: "train loss:"0.67884, "train acc: "0.53125
# 1: "train loss:"0.69369, "train acc: "0.52885
# 1: "train loss:"0.68720, "train acc: "0.52163
# 1: "train loss:"0.67730, "train acc: "0.56971
# 1: "train loss:"0.68961, "train acc: "0.51923
# 1: "train loss:"0.69647, "train acc: "0.52644
# 1: "train loss:"0.68664, "train acc: "0.54327
# 1: "train loss:"0.68288, "train acc: "0.56490
# 1: "train loss:"0.68303, "train acc: "0.54567
# 1: "train loss:"0.68240, "train acc: "0.54327
# 1: "train loss:"0.68263, "train acc: "0.56010
# 1: "train loss:"0.68319, "train acc: "0.57452
# 1: "train loss:"0.68960, "train acc: "0.51683
# 1: "train loss:"0.68380, "train acc: "0.53365
# 1: "train loss:"0.68388, "train acc: "0.53846
# 1: "train loss:"0.68512, "train acc: "0.55048
# 1: "train loss:"0.68688, "train acc: "0.53846
# 1: "train loss:"0.68351, "train acc: "0.55048
# 1: "train loss:"0.67452, "train acc: "0.54808
# 1: "train loss:"0.68991, "train acc: "0.52163
# 1: "train loss:"0.68922, "train acc: "0.55769
# 1: "train loss:"0.68477, "train acc: "0.55288
# 1: "train loss:"0.68580, "train acc: "0.52644
# 1: "train loss:"0.68564, "train acc: "0.54327
# 1: "train loss:"0.67942, "train acc: "0.56731
# 1: "train loss:"0.68879, "train acc: "0.54087
# 1: "train loss:"0.68158, "train acc: "0.51683
# 1: "train loss:"0.68289, "train acc: "0.56010
# 1: "train loss:"0.67678, "train acc: "0.53365
# 1: "train loss:"0.68952, "train acc: "0.53125
# 1: "train loss:"0.68829, "train acc: "0.51923
# 1: "train loss:"0.68945, "train acc: "0.53365
# 1: "train loss:"0.69015, "train acc: "0.53846
# 1: "train loss:"0.68534, "train acc: "0.54567
# 1: "train loss:"0.67851, "train acc: "0.56731
# 1: "train loss:"0.68474, "train acc: "0.55769
# 1: "train loss:"0.68616, "train acc: "0.52163
# 1: "train loss:"0.68466, "train acc: "0.52885
# 1: "train loss:"0.67766, "train acc: "0.52885
# 1: "train loss:"0.70115, "train acc: "0.54567
# 1: "train loss:"0.67158, "train acc: "0.56010
# 1: "train loss:"0.67881, "train acc: "0.55529
# 1: "train loss:"0.68771, "train acc: "0.52885
# 1: "train loss:"0.69063, "train acc: "0.53846
# 1: "train loss:"0.68379, "train acc: "0.56010
# 1: "train loss:"0.68415, "train acc: "0.56250
# 1: "train loss:"0.69241, "train acc: "0.53846
# 1: "train loss:"0.68700, "train acc: "0.55288
# 1: "train loss:"0.67200, "train acc: "0.54327
# 1: "train loss:"0.67461, "train acc: "0.51683
# 1: "train loss:"0.67958, "train acc: "0.56250
# 1: "train loss:"0.67795, "train acc: "0.53125
# 1: "train loss:"0.68856, "train acc: "0.52644
# 1: "train loss:"0.68777, "train acc: "0.55288
# 1: "train loss:"0.68443, "train acc: "0.53125
# 1: "train loss:"0.68300, "train acc: "0.53846
# 1: "train loss:"0.68475, "train acc: "0.55288
# 1: "train loss:"0.66945, "train acc: "0.56250
# 1: "train loss:"0.68303, "train acc: "0.55048
# 1: "train loss:"0.67901, "train acc: "0.54327
# 1: "train loss:"0.68466, "train acc: "0.56490
# 1: "train loss:"0.67975, "train acc: "0.53125
# 1: "train loss:"0.68387, "train acc: "0.53365
# 1: "train loss:"0.68978, "train acc: "0.51442
# 1: "train loss:"0.67736, "train acc: "0.53365
# 1: "train loss:"0.68348, "train acc: "0.55769
# 1: "train loss:"0.68307, "train acc: "0.54808
# 1: "train loss:"0.67770, "train acc: "0.54327
# 1: "train loss:"0.68643, "train acc: "0.52885
# 1: "train loss:"0.67569, "train acc: "0.56250
# 1: "train loss:"0.68141, "train acc: "0.55288
# 1: "train loss:"0.68692, "train acc: "0.51202
# 1: "train loss:"0.68133, "train acc: "0.53365
# 1: "train loss:"0.68529, "train acc: "0.54567
# 1: "train loss:"0.68752, "train acc: "0.51683
# 1: "train loss:"0.67860, "train acc: "0.56010
# 1: "train loss:"0.68837, "train acc: "0.54567
# 1: "train loss:"0.68120, "train acc: "0.56250
# 1: "train loss:"0.68576, "train acc: "0.54327
# 1: "train loss:"0.67580, "train acc: "0.55288
# 1: "train loss:"0.67383, "train acc: "0.56250
# 1: "train loss:"0.67923, "train acc: "0.53606
# 1: "train loss:"0.67935, "train acc: "0.55288
# 1: "train loss:"0.67395, "train acc: "0.54567
# 1: "train loss:"0.69269, "train acc: "0.52885
# 1: "train loss:"0.67906, "train acc: "0.53125
# 1: "train loss:"0.67238, "train acc: "0.55288
# 1: "train loss:"0.68281, "train acc: "0.52404
# 1: "train loss:"0.67881, "train acc: "0.54567
# 1: "train loss:"0.68563, "train acc: "0.53846
# 1: "train loss:"0.68217, "train acc: "0.54087
# 1: "train loss:"0.68837, "train acc: "0.55048
# 1: "train loss:"0.67599, "train acc: "0.56490
# 1: "train loss:"0.68134, "train acc: "0.54567
# 1: "train loss:"0.67847, "train acc: "0.54567
# 1: "train loss:"0.68909, "train acc: "0.53125
# 1: "train loss:"0.67058, "train acc: "0.54808
# 1: "train loss:"0.68620, "train acc: "0.52885
# 1: "train loss:"0.69104, "train acc: "0.53846
# 1: "train loss:"0.68390, "train acc: "0.53365
# 1: "train loss:"0.68664, "train acc: "0.57452
# 1: "train loss:"0.69774, "train acc: "0.51923
# 1: "train loss:"0.67845, "train acc: "0.51923
# 1: "train loss:"0.67223, "train acc: "0.52644
# 1: "train loss:"0.67944, "train acc: "0.51683
# 1: "train loss:"0.68013, "train acc: "0.53365
# 1: "train loss:"0.68806, "train acc: "0.53846
# 1: "train loss:"0.68071, "train acc: "0.53606
# 1: "train loss:"0.69001, "train acc: "0.53606
# 1: "train loss:"0.68150, "train acc: "0.53125
# 1: "train loss:"0.68530, "train acc: "0.55529
# 1: "train loss:"0.69773, "train acc: "0.52885
# 1: "train loss:"0.68216, "train acc: "0.54808
# 1: "train loss:"0.67001, "train acc: "0.55288
# 1: "train loss:"0.69145, "train acc: "0.52404
# 1: "train loss:"0.68242, "train acc: "0.53606
# 1: "train loss:"0.67867, "train acc: "0.56010
# 1: "train loss:"0.67676, "train acc: "0.51442
# 1: "train loss:"0.68506, "train acc: "0.52404
# 1: "train loss:"0.67716, "train acc: "0.55769
# 1: "train loss:"0.67557, "train acc: "0.54808
# 1: "train loss:"0.67335, "train acc: "0.53365
# 1: "train loss:"0.66167, "train acc: "0.54087
# 1: "train loss:"0.66907, "train acc: "0.55048
# 1: "train loss:"0.67408, "train acc: "0.57212
# 1: "train loss:"0.67020, "train acc: "0.55048
# 1: "train loss:"0.68147, "train acc: "0.54327
# 1: "train loss:"0.65782, "train acc: "0.55529
# 1: "train loss:"0.67115, "train acc: "0.56010
# 1: "train loss:"0.67951, "train acc: "0.56010
# 1: "train loss:"0.68479, "train acc: "0.52404
# 1: "train loss:"0.68608, "train acc: "0.50481
# 1: "train loss:"0.67421, "train acc: "0.55048
# 1: "train loss:"0.66634, "train acc: "0.57212
# 1: "train loss:"0.68955, "train acc: "0.55048
# 1: "train loss:"0.67328, "train acc: "0.53365
# 1: "train loss:"0.68873, "train acc: "0.54327
# 1: "train loss:"0.67687, "train acc: "0.53365
# 1: "train loss:"0.66569, "train acc: "0.53846
# 1: "train loss:"0.69072, "train acc: "0.53365
# 1: "train loss:"0.66764, "train acc: "0.56490
# 1: "train loss:"0.68156, "train acc: "0.54087
# 1: "train loss:"0.68003, "train acc: "0.54087
# 1: "train loss:"0.69265, "train acc: "0.51442
# 1: "train loss:"0.68007, "train acc: "0.53606
# 1: "train loss:"0.68229, "train acc: "0.53606
# 1: "train loss:"0.68271, "train acc: "0.52163
# 1: "train loss:"0.68212, "train acc: "0.54808
# 1: "train loss:"0.67935, "train acc: "0.52644
# 1: "train loss:"0.67532, "train acc: "0.56250
# 1: "train loss:"0.67125, "train acc: "0.57212
# 1: "train loss:"0.68582, "train acc: "0.53846
# 1: "train loss:"0.67979, "train acc: "0.54327
# 1: "train loss:"0.67919, "train acc: "0.55288
# 1: "train loss:"0.66077, "train acc: "0.54567
# 1: "train loss:"0.68493, "train acc: "0.53846
# 1: "train loss:"0.68377, "train acc: "0.55048
# 1: "train loss:"0.67614, "train acc: "0.57212
# 1: "train loss:"0.66950, "train acc: "0.53606
# 1: "train loss:"0.68212, "train acc: "0.53365
# 1: "train loss:"0.68798, "train acc: "0.53365
# 1: "train loss:"0.67636, "train acc: "0.52885
# 1: "train loss:"0.67967, "train acc: "0.51442
# 1: "train loss:"0.68519, "train acc: "0.54327
# 1: "train loss:"0.68020, "train acc: "0.55288
# 1: "train loss:"0.67654, "train acc: "0.55288
# 1: "train loss:"0.67437, "train acc: "0.56731
# 1: "train loss:"0.67288, "train acc: "0.53846
# 1: "train loss:"0.67480, "train acc: "0.55769
# 1: "train loss:"0.68847, "train acc: "0.50240
# 1: "train loss:"0.67968, "train acc: "0.55048
# 1: "train loss:"0.68065, "train acc: "0.56490
# 1: "train loss:"0.69451, "train acc: "0.54567
# 1: "train loss:"0.67894, "train acc: "0.52885
# 1: "train loss:"0.67557, "train acc: "0.50721
# 1: "train loss:"0.67491, "train acc: "0.53125
# 1: "train loss:"0.67403, "train acc: "0.53365
# 1: "train loss:"0.66679, "train acc: "0.55529
# 1: "train loss:"0.66519, "train acc: "0.53846
# 1: "train loss:"0.65672, "train acc: "0.54567
# 1: "train loss:"0.67650, "train acc: "0.54567
# 1: "train loss:"0.68261, "train acc: "0.54808
# 1: "train loss:"0.69765, "train acc: "0.50481
# 1: "train loss:"0.68643, "train acc: "0.52885
# 1: "train loss:"0.68180, "train acc: "0.53125
# 1: "train loss:"0.66663, "train acc: "0.54327
# 1: "train loss:"0.68917, "train acc: "0.55048
# 1: "train loss:"0.68369, "train acc: "0.55529
# 1: "train loss:"0.67935, "train acc: "0.56010
# 1: "train loss:"0.69567, "train acc: "0.50721
# 1: "train loss:"0.67044, "train acc: "0.51923
# 1: "train loss:"0.67775, "train acc: "0.53606
# 1: "train loss:"0.68717, "train acc: "0.51683
# 1: "train loss:"0.68006, "train acc: "0.55048
# 1: "train loss:"0.68482, "train acc: "0.49519
# 1: "train loss:"0.67101, "train acc: "0.54567
# 1: "train loss:"0.67395, "train acc: "0.56490
# 1: "train loss:"0.68857, "train acc: "0.52644
# 1: "train loss:"0.66797, "train acc: "0.57212
# 1: "train loss:"0.68873, "train acc: "0.53606
# 1: "train loss:"0.68112, "train acc: "0.54808
# 1: "train loss:"0.67590, "train acc: "0.55529
# 1: "train loss:"0.68594, "train acc: "0.53846
# 1: "train loss:"0.66993, "train acc: "0.57692
# 1: "train loss:"0.66779, "train acc: "0.55288
# 1: "train loss:"0.67290, "train acc: "0.54087
# 1: "train loss:"0.67948, "train acc: "0.51683
# 1: "train loss:"0.67444, "train acc: "0.53125
# 1: "train loss:"0.68511, "train acc: "0.54808
# 1: "train loss:"0.67408, "train acc: "0.55048
# 1: "train loss:"0.68570, "train acc: "0.56010
# 1: "train loss:"0.68065, "train acc: "0.52404
# 1: "train loss:"0.66705, "train acc: "0.52885
# 1: "train loss:"0.68475, "train acc: "0.55529
# 1: "train loss:"0.67487, "train acc: "0.54087
# 1: "train loss:"0.66360, "train acc: "0.56250
# 1: "train loss:"0.66399, "train acc: "0.55288
# 1: "train loss:"0.69102, "train acc: "0.53125
# 1: "train loss:"0.67519, "train acc: "0.53365
# 1: "train loss:"0.68329, "train acc: "0.51442
# 1: "train loss:"0.67059, "train acc: "0.56490
# 1: "train loss:"0.66789, "train acc: "0.52163
# 1: "train loss:"0.66702, "train acc: "0.56250
# 1: "train loss:"0.66683, "train acc: "0.55769
# 1: "train loss:"0.66100, "train acc: "0.56490
# 1: "train loss:"0.67741, "train acc: "0.57933
# 1: "train loss:"0.68795, "train acc: "0.53365
# 1: "train loss:"0.67195, "train acc: "0.51923
# 1: "train loss:"0.67043, "train acc: "0.52404
# 1: "train loss:"0.69153, "train acc: "0.51683
# 1: "train loss:"0.67624, "train acc: "0.55288
# 1: "train loss:"0.67061, "train acc: "0.56490
# 1: "train loss:"0.69594, "train acc: "0.52404
# 1: "train loss:"0.66148, "train acc: "0.53365
# 1: "train loss:"0.67551, "train acc: "0.53846
# 1: "train loss:"0.65938, "train acc: "0.52404
# 1: "train loss:"0.67648, "train acc: "0.54087
# 1: "train loss:"0.68051, "train acc: "0.56010
# 1: "train loss:"0.65501, "train acc: "0.57692
# 1: "train loss:"0.68645, "train acc: "0.53606
# 1: "train loss:"0.66424, "train acc: "0.53846
# 1: "train loss:"0.68551, "train acc: "0.54327
# 1: "train loss:"0.67760, "train acc: "0.55529
# 1: "train loss:"0.67586, "train acc: "0.52644
# 1: "train loss:"0.66693, "train acc: "0.55529
# 1: "val loss:"0.69320, "val acc: "0.53365
# 1: "val loss:"0.68995, "val acc: "0.53846
# 1: "val loss:"0.66710, "val acc: "0.56250
# 1: "val loss:"0.66056, "val acc: "0.55769
# 1: "val loss:"0.66266, "val acc: "0.60096
# 1: "val loss:"0.69235, "val acc: "0.54327
# 1: "val loss:"0.65384, "val acc: "0.58173
# 1: "val loss:"0.68539, "val acc: "0.52404
# 1: "val loss:"0.69818, "val acc: "0.58173
# 1: "val loss:"0.64458, "val acc: "0.59135
# 1: "val loss:"0.67986, "val acc: "0.56250
# 1: "val loss:"0.65780, "val acc: "0.54327
# 1: "val loss:"0.64346, "val acc: "0.62981
# 1: "val loss:"0.69756, "val acc: "0.55769
# 1: "val loss:"0.67266, "val acc: "0.55769
# 1: "val loss:"0.69679, "val acc: "0.57212
# 1: "val loss:"0.66298, "val acc: "0.60577
# 1: "val loss:"0.66286, "val acc: "0.58654
# 1: "val loss:"0.68846, "val acc: "0.52404
# 1: "val loss:"0.66857, "val acc: "0.55769
# 1: "val loss:"0.68603, "val acc: "0.56731
# 1: "val loss:"0.65608, "val acc: "0.56731
# 1: "val loss:"0.65595, "val acc: "0.54327
# 1: "val loss:"0.67972, "val acc: "0.53846
# 1: "val loss:"0.65853, "val acc: "0.60096
# 1: "val loss:"0.68743, "val acc: "0.57212
# 1: "val loss:"0.64317, "val acc: "0.56731
# 1: "val loss:"0.65604, "val acc: "0.57212
# 1: "val loss:"0.67169, "val acc: "0.58654
# 1: "val loss:"0.66898, "val acc: "0.55769
# 1: "val loss:"0.65740, "val acc: "0.55769
# 1: "val loss:"0.68287, "val acc: "0.56250
# 1: "val loss:"0.66515, "val acc: "0.59135
# 1: "val loss:"0.65082, "val acc: "0.56731
# 1: "val loss:"0.66940, "val acc: "0.57212
# 1: "val loss:"0.63996, "val acc: "0.57692
# 1: "val loss:"0.64178, "val acc: "0.62019
# 1: "val loss:"0.63712, "val acc: "0.60096
# 1: "val loss:"0.65169, "val acc: "0.58173
# 1: "val loss:"0.67175, "val acc: "0.55288
# 1: "val loss:"0.66978, "val acc: "0.54327
# 1: "val loss:"0.63854, "val acc: "0.58173
# 1: "val loss:"0.69488, "val acc: "0.56731
# 1: "val loss:"0.65559, "val acc: "0.58173
# 1: "val loss:"0.65066, "val acc: "0.58173
# 1: "val loss:"0.65015, "val acc: "0.57692
# 1: "val loss:"0.66366, "val acc: "0.54808
# 1: "val loss:"0.64391, "val acc: "0.55769
# 1: "val loss:"0.67677, "val acc: "0.55769
# 1: "val loss:"0.64755, "val acc: "0.59615
# 1: "val loss:"0.65724, "val acc: "0.57692
# 1: "val loss:"0.67934, "val acc: "0.55288
# 1: "val loss:"0.65244, "val acc: "0.55769
# 1: "val loss:"0.65580, "val acc: "0.56250
# 1: "val loss:"0.67160, "val acc: "0.58173
# 1: "val loss:"0.64840, "val acc: "0.58654
# 1: "val loss:"0.65790, "val acc: "0.57212
# 1: "val loss:"0.65801, "val acc: "0.54327
# 1: "val loss:"0.66752, "val acc: "0.55288
# 1: "val loss:"0.68426, "val acc: "0.55769
# 1: "val loss:"0.64837, "val acc: "0.59615
# 1: "val loss:"0.63017, "val acc: "0.58654
# 1: "val loss:"0.67164, "val acc: "0.57212
# 1: "val loss:"0.68577, "val acc: "0.55288
# 1: "val loss:"0.66754, "val acc: "0.56250
# 1: "val loss:"0.63144, "val acc: "0.60577
# 1: "val loss:"0.64549, "val acc: "0.58654
# 1: "val loss:"0.67359, "val acc: "0.57692
# 1: "val loss:"0.64797, "val acc: "0.58654
# 1: "val loss:"0.69845, "val acc: "0.56731
# 1: "val loss:"0.65717, "val acc: "0.58173
# 1: "val loss:"0.67371, "val acc: "0.58173
# 1: "val loss:"0.66264, "val acc: "0.60577
# 1: "val loss:"0.66595, "val acc: "0.57692
# 1: "val loss:"0.67113, "val acc: "0.53365
# 1: "val loss:"0.66074, "val acc: "0.55769
# 1: "val loss:"0.62871, "val acc: "0.61538
# 1: "val loss:"0.65512, "val acc: "0.59135
# 1: "val loss:"0.65762, "val acc: "0.59135
# 1: "val loss:"0.64362, "val acc: "0.61058
# 1: "val loss:"0.67306, "val acc: "0.54808
# 1: "val loss:"0.64054, "val acc: "0.62500
# 1: "val loss:"0.63149, "val acc: "0.59615
# 1: "val loss:"0.64568, "val acc: "0.55769
# 1: "val loss:"0.65579, "val acc: "0.59615
# 1: "val loss:"0.69167, "val acc: "0.54808
# 1: "val loss:"0.66812, "val acc: "0.54327
# 1: "val loss:"0.63555, "val acc: "0.59135
# 1: "val loss:"0.64923, "val acc: "0.58173
# 1: "val loss:"0.63004, "val acc: "0.60096
# 1: "val loss:"0.68098, "val acc: "0.54327
# 1: "val loss:"0.66250, "val acc: "0.53846
# 1: "val loss:"0.65224, "val acc: "0.59615
# 1: "val loss:"0.69561, "val acc: "0.54808
# 1: "val loss:"0.67856, "val acc: "0.57212
# 1: "val loss:"0.65673, "val acc: "0.59135
# 1: "val loss:"0.69480, "val acc: "0.50962
# 1: "val loss:"0.67198, "val acc: "0.56731
# 1: "val loss:"0.64344, "val acc: "0.59135
# 1: "val loss:"0.68479, "val acc: "0.57212
# 1: "val loss:"0.64546, "val acc: "0.61058
# 1: "val loss:"0.68102, "val acc: "0.59135
# 1: "val loss:"0.65669, "val acc: "0.62019
# 1: "val loss:"0.67096, "val acc: "0.55288
# 1: "val loss:"0.65733, "val acc: "0.54327
# 1: "val loss:"0.67193, "val acc: "0.58173
# 1: "val loss:"0.62461, "val acc: "0.59135
# 1: "val loss:"0.66824, "val acc: "0.58173
# 1: "val loss:"0.66368, "val acc: "0.56731
# 1: "val loss:"0.65603, "val acc: "0.56250
# 1: "val loss:"0.67397, "val acc: "0.56731
# 1: "val loss:"0.67212, "val acc: "0.56250
# 1: "val loss:"0.65930, "val acc: "0.58173
# 1: "val loss:"0.69109, "val acc: "0.54327
# 1: "val loss:"0.65571, "val acc: "0.56250
# 1: "val loss:"0.66696, "val acc: "0.58654
# 1: "val loss:"0.66617, "val acc: "0.59615
# 1: "val loss:"0.66378, "val acc: "0.55769
# 1: "val loss:"0.66000, "val acc: "0.59135
# 1: "val loss:"0.66523, "val acc: "0.57212
# 1: "val loss:"0.66933, "val acc: "0.57692
# 1: "val loss:"0.66077, "val acc: "0.58654
# 1: "val loss:"0.63772, "val acc: "0.59135
# 1: "val loss:"0.68431, "val acc: "0.53846
# 1: "val loss:"0.66483, "val acc: "0.54808
# 2: "train loss:"0.68339, "train acc: "0.55048
# 2: "train loss:"0.66447, "train acc: "0.51202
# 2: "train loss:"0.67156, "train acc: "0.53125
# 2: "train loss:"0.67508, "train acc: "0.54808
# 2: "train loss:"0.68699, "train acc: "0.53125
# 2: "train loss:"0.66781, "train acc: "0.55769
# 2: "train loss:"0.68243, "train acc: "0.52885
# 2: "train loss:"0.66717, "train acc: "0.53365
# 2: "train loss:"0.64756, "train acc: "0.56490
# 2: "train loss:"0.69345, "train acc: "0.53846
# 2: "train loss:"0.68756, "train acc: "0.54567
# 2: "train loss:"0.68395, "train acc: "0.54808
# 2: "train loss:"0.67251, "train acc: "0.57933
# 2: "train loss:"0.64873, "train acc: "0.56010
# 2: "train loss:"0.68067, "train acc: "0.54808
# 2: "train loss:"0.68829, "train acc: "0.55288
# 2: "train loss:"0.68304, "train acc: "0.58173
# 2: "train loss:"0.67632, "train acc: "0.52885
# 2: "train loss:"0.67021, "train acc: "0.54567
# 2: "train loss:"0.66668, "train acc: "0.56010
# 2: "train loss:"0.68402, "train acc: "0.55288
# 2: "train loss:"0.69009, "train acc: "0.54808
# 2: "train loss:"0.67129, "train acc: "0.57452
# 2: "train loss:"0.66907, "train acc: "0.55288
# 2: "train loss:"0.69236, "train acc: "0.52885
# 2: "train loss:"0.67140, "train acc: "0.55769
# 2: "train loss:"0.66534, "train acc: "0.56010
# 2: "train loss:"0.67401, "train acc: "0.54327
# 2: "train loss:"0.67306, "train acc: "0.51923
# 2: "train loss:"0.67755, "train acc: "0.55769
# 2: "train loss:"0.68688, "train acc: "0.55769
# 2: "train loss:"0.68099, "train acc: "0.51442
# 2: "train loss:"0.68927, "train acc: "0.57212
# 2: "train loss:"0.67333, "train acc: "0.54567
# 2: "train loss:"0.66854, "train acc: "0.53846
# 2: "train loss:"0.67874, "train acc: "0.55288
# 2: "train loss:"0.68069, "train acc: "0.53606
# 2: "train loss:"0.68999, "train acc: "0.54567
# 2: "train loss:"0.67132, "train acc: "0.52644
# 2: "train loss:"0.67274, "train acc: "0.56731
# 2: "train loss:"0.67891, "train acc: "0.55769
# 2: "train loss:"0.66355, "train acc: "0.55769
# 2: "train loss:"0.68586, "train acc: "0.53365
# 2: "train loss:"0.67934, "train acc: "0.54327
# 2: "train loss:"0.68049, "train acc: "0.56731
# 2: "train loss:"0.66540, "train acc: "0.54808
# 2: "train loss:"0.66211, "train acc: "0.56250
# 2: "train loss:"0.66765, "train acc: "0.54327
# 2: "train loss:"0.67651, "train acc: "0.52885
# 2: "train loss:"0.65326, "train acc: "0.54567
# 2: "train loss:"0.69254, "train acc: "0.55288
# 2: "train loss:"0.68211, "train acc: "0.51923
# 2: "train loss:"0.66124, "train acc: "0.52885
# 2: "train loss:"0.67490, "train acc: "0.57212
# 2: "train loss:"0.67257, "train acc: "0.52644
# 2: "train loss:"0.68416, "train acc: "0.56010
# 2: "train loss:"0.69101, "train acc: "0.54087
# 2: "train loss:"0.67064, "train acc: "0.51683
# 2: "train loss:"0.66747, "train acc: "0.55529
# 2: "train loss:"0.66396, "train acc: "0.56490
# 2: "train loss:"0.66601, "train acc: "0.51442
# 2: "train loss:"0.67795, "train acc: "0.57692
# 2: "train loss:"0.67074, "train acc: "0.56971
# 2: "train loss:"0.67887, "train acc: "0.54567
# 2: "train loss:"0.68005, "train acc: "0.55048
# 2: "train loss:"0.65816, "train acc: "0.57452
# 2: "train loss:"0.67551, "train acc: "0.55288
# 2: "train loss:"0.68436, "train acc: "0.51923
# 2: "train loss:"0.69805, "train acc: "0.51202
# 2: "train loss:"0.66107, "train acc: "0.56250
# 2: "train loss:"0.68095, "train acc: "0.56490
# 2: "train loss:"0.67141, "train acc: "0.56731
# 2: "train loss:"0.66665, "train acc: "0.55288
# 2: "train loss:"0.68757, "train acc: "0.54567
# 2: "train loss:"0.67554, "train acc: "0.54087
# 2: "train loss:"0.64399, "train acc: "0.57452
# 2: "train loss:"0.65884, "train acc: "0.49038
# 2: "train loss:"0.65533, "train acc: "0.55048
# 2: "train loss:"0.68564, "train acc: "0.55048
# 2: "train loss:"0.67526, "train acc: "0.54327
# 2: "train loss:"0.66731, "train acc: "0.55769
# 2: "train loss:"0.67772, "train acc: "0.53606
# 2: "train loss:"0.67164, "train acc: "0.56731
# 2: "train loss:"0.68195, "train acc: "0.55288
# 2: "train loss:"0.68553, "train acc: "0.55288
# 2: "train loss:"0.65786, "train acc: "0.58413
# 2: "train loss:"0.65729, "train acc: "0.55048
# 2: "train loss:"0.66165, "train acc: "0.53606
# 2: "train loss:"0.67589, "train acc: "0.52885
# 2: "train loss:"0.69265, "train acc: "0.53606
# 2: "train loss:"0.66565, "train acc: "0.54327
# 2: "train loss:"0.65727, "train acc: "0.55769
# 2: "train loss:"0.66224, "train acc: "0.51442
# 2: "train loss:"0.68007, "train acc: "0.55048
# 2: "train loss:"0.67282, "train acc: "0.56490
# 2: "train loss:"0.67130, "train acc: "0.51683
# 2: "train loss:"0.66290, "train acc: "0.54567
# 2: "train loss:"0.67672, "train acc: "0.57212
# 2: "train loss:"0.66810, "train acc: "0.57452
# 2: "train loss:"0.68141, "train acc: "0.54327
# 2: "train loss:"0.68667, "train acc: "0.53606
# 2: "train loss:"0.65271, "train acc: "0.56250
# 2: "train loss:"0.68248, "train acc: "0.53125
# 2: "train loss:"0.68053, "train acc: "0.52404
# 2: "train loss:"0.67179, "train acc: "0.53846
# 2: "train loss:"0.65712, "train acc: "0.57212
# 2: "train loss:"0.67335, "train acc: "0.51683
# 2: "train loss:"0.67119, "train acc: "0.53606
# 2: "train loss:"0.67043, "train acc: "0.55529
# 2: "train loss:"0.65648, "train acc: "0.55288
# 2: "train loss:"0.67277, "train acc: "0.56250
# 2: "train loss:"0.66314, "train acc: "0.57452
# 2: "train loss:"0.67466, "train acc: "0.54567
# 2: "train loss:"0.68605, "train acc: "0.54808
# 2: "train loss:"0.66554, "train acc: "0.52644
# 2: "train loss:"0.66460, "train acc: "0.55048
# 2: "train loss:"0.65796, "train acc: "0.56490
# 2: "train loss:"0.65135, "train acc: "0.58654
# 2: "train loss:"0.67138, "train acc: "0.56250
# 2: "train loss:"0.67899, "train acc: "0.53125
# 2: "train loss:"0.66042, "train acc: "0.54327
# 2: "train loss:"0.64996, "train acc: "0.58173
# 2: "train loss:"0.64722, "train acc: "0.56971
# 2: "train loss:"0.68324, "train acc: "0.52885
# 2: "train loss:"0.65982, "train acc: "0.57933
# 2: "train loss:"0.64887, "train acc: "0.55288
# 2: "train loss:"0.67540, "train acc: "0.55529
# 2: "train loss:"0.67032, "train acc: "0.54567
# 2: "train loss:"0.66111, "train acc: "0.52885
# 2: "train loss:"0.66434, "train acc: "0.55529
# 2: "train loss:"0.65947, "train acc: "0.52404
# 2: "train loss:"0.66312, "train acc: "0.57452
# 2: "train loss:"0.67575, "train acc: "0.57212
# 2: "train loss:"0.66073, "train acc: "0.56731
# 2: "train loss:"0.66713, "train acc: "0.57452
# 2: "train loss:"0.68389, "train acc: "0.53365
# 2: "train loss:"0.65644, "train acc: "0.55529
# 2: "train loss:"0.65887, "train acc: "0.57692
# 2: "train loss:"0.67302, "train acc: "0.59135
# 2: "train loss:"0.66565, "train acc: "0.53606
# 2: "train loss:"0.67773, "train acc: "0.54808
# 2: "train loss:"0.67268, "train acc: "0.56250
# 2: "train loss:"0.67887, "train acc: "0.54087
# 2: "train loss:"0.64359, "train acc: "0.57933
# 2: "train loss:"0.67391, "train acc: "0.54327
# 2: "train loss:"0.66881, "train acc: "0.56971
# 2: "train loss:"0.68972, "train acc: "0.53365
# 2: "train loss:"0.69166, "train acc: "0.55048
# 2: "train loss:"0.68581, "train acc: "0.52885
# 2: "train loss:"0.67968, "train acc: "0.54808
# 2: "train loss:"0.67971, "train acc: "0.54808
# 2: "train loss:"0.67551, "train acc: "0.52644
# 2: "train loss:"0.67426, "train acc: "0.55288
# 2: "train loss:"0.67407, "train acc: "0.54808
# 2: "train loss:"0.68108, "train acc: "0.57933
# 2: "train loss:"0.65092, "train acc: "0.58413
# 2: "train loss:"0.67068, "train acc: "0.52404
# 2: "train loss:"0.66844, "train acc: "0.56250
# 2: "train loss:"0.67841, "train acc: "0.55529
# 2: "train loss:"0.64214, "train acc: "0.59615
# 2: "train loss:"0.68313, "train acc: "0.55048
# 2: "train loss:"0.65526, "train acc: "0.56490
# 2: "train loss:"0.68383, "train acc: "0.56010
# 2: "train loss:"0.66479, "train acc: "0.55288
# 2: "train loss:"0.66651, "train acc: "0.56731
# 2: "train loss:"0.69279, "train acc: "0.53365
# 2: "train loss:"0.65942, "train acc: "0.54567
# 2: "train loss:"0.68723, "train acc: "0.52885
# 2: "train loss:"0.65881, "train acc: "0.54327
# 2: "train loss:"0.67143, "train acc: "0.56010
# 2: "train loss:"0.67572, "train acc: "0.56731
# 2: "train loss:"0.66087, "train acc: "0.53606
# 2: "train loss:"0.66343, "train acc: "0.56731
# 2: "train loss:"0.66020, "train acc: "0.57933
# 2: "train loss:"0.67857, "train acc: "0.51923
# 2: "train loss:"0.68623, "train acc: "0.53846
# 2: "train loss:"0.68443, "train acc: "0.55288
# 2: "train loss:"0.66148, "train acc: "0.53606
# 2: "train loss:"0.66929, "train acc: "0.53606
# 2: "train loss:"0.68447, "train acc: "0.52644
# 2: "train loss:"0.66265, "train acc: "0.57212
# 2: "train loss:"0.67737, "train acc: "0.54808
# 2: "train loss:"0.64944, "train acc: "0.52404
# 2: "train loss:"0.63183, "train acc: "0.51442
# 2: "train loss:"0.66125, "train acc: "0.58654
# 2: "train loss:"0.67452, "train acc: "0.52644
# 2: "train loss:"0.66421, "train acc: "0.57452
# 2: "train loss:"0.67963, "train acc: "0.53606
# 2: "train loss:"0.67505, "train acc: "0.53606
# 2: "train loss:"0.66543, "train acc: "0.56731
# 2: "train loss:"0.65918, "train acc: "0.56490
# 2: "train loss:"0.65294, "train acc: "0.59135
# 2: "train loss:"0.67568, "train acc: "0.58894
# 2: "train loss:"0.68204, "train acc: "0.54567
# 2: "train loss:"0.68545, "train acc: "0.52163
# 2: "train loss:"0.65129, "train acc: "0.57452
# 2: "train loss:"0.68581, "train acc: "0.53125
# 2: "train loss:"0.68934, "train acc: "0.52404
# 2: "train loss:"0.68724, "train acc: "0.54327
# 2: "train loss:"0.66000, "train acc: "0.52885
# 2: "train loss:"0.65749, "train acc: "0.56490
# 2: "train loss:"0.65631, "train acc: "0.52885
# 2: "train loss:"0.69009, "train acc: "0.55288
# 2: "train loss:"0.67029, "train acc: "0.56971
# 2: "train loss:"0.67528, "train acc: "0.56250
# 2: "train loss:"0.67457, "train acc: "0.56731
# 2: "train loss:"0.66141, "train acc: "0.55288
# 2: "train loss:"0.66674, "train acc: "0.54327
# 2: "train loss:"0.64296, "train acc: "0.60096
# 2: "train loss:"0.66350, "train acc: "0.57452
# 2: "train loss:"0.66917, "train acc: "0.50721
# 2: "train loss:"0.68943, "train acc: "0.53846
# 2: "train loss:"0.67435, "train acc: "0.54327
# 2: "train loss:"0.66934, "train acc: "0.57933
# 2: "train loss:"0.65352, "train acc: "0.59135
# 2: "train loss:"0.67606, "train acc: "0.56250
# 2: "train loss:"0.65022, "train acc: "0.55288
# 2: "train loss:"0.67429, "train acc: "0.54087
# 2: "train loss:"0.67632, "train acc: "0.55288
# 2: "train loss:"0.68065, "train acc: "0.55769
# 2: "train loss:"0.63889, "train acc: "0.54567
# 2: "train loss:"0.66631, "train acc: "0.52644
# 2: "train loss:"0.66935, "train acc: "0.57212
# 2: "train loss:"0.66880, "train acc: "0.56490
# 2: "train loss:"0.68807, "train acc: "0.51442
# 2: "train loss:"0.64701, "train acc: "0.53606
# 2: "train loss:"0.65890, "train acc: "0.51202
# 2: "train loss:"0.68716, "train acc: "0.56971
# 2: "train loss:"0.64669, "train acc: "0.60577
# 2: "train loss:"0.68139, "train acc: "0.55529
# 2: "train loss:"0.64882, "train acc: "0.58894
# 2: "train loss:"0.66610, "train acc: "0.54087
# 2: "train loss:"0.66774, "train acc: "0.56250
# 2: "train loss:"0.68292, "train acc: "0.54808
# 2: "train loss:"0.67118, "train acc: "0.53365
# 2: "train loss:"0.67882, "train acc: "0.50962
# 2: "train loss:"0.64464, "train acc: "0.56490
# 2: "train loss:"0.67782, "train acc: "0.54567
# 2: "train loss:"0.67518, "train acc: "0.51202
# 2: "train loss:"0.67655, "train acc: "0.55048
# 2: "train loss:"0.65255, "train acc: "0.51442
# 2: "train loss:"0.65144, "train acc: "0.54327
# 2: "train loss:"0.67081, "train acc: "0.54567
# 2: "train loss:"0.63915, "train acc: "0.61058
# 2: "train loss:"0.65850, "train acc: "0.57452
# 2: "train loss:"0.65876, "train acc: "0.58894
# 2: "train loss:"0.67769, "train acc: "0.56971
# 2: "train loss:"0.66322, "train acc: "0.53125
# 2: "train loss:"0.65119, "train acc: "0.57692
# 2: "train loss:"0.62019, "train acc: "0.61538
# 2: "val loss:"0.64274, "val acc: "0.59615
# 2: "val loss:"0.65807, "val acc: "0.59615
# 2: "val loss:"0.65291, "val acc: "0.58173
# 2: "val loss:"0.65391, "val acc: "0.57692
# 2: "val loss:"0.68347, "val acc: "0.57692
# 2: "val loss:"0.69652, "val acc: "0.55288
# 2: "val loss:"0.64234, "val acc: "0.62500
# 2: "val loss:"0.69271, "val acc: "0.54808
# 2: "val loss:"0.67049, "val acc: "0.61538
# 2: "val loss:"0.64651, "val acc: "0.60096
# 2: "val loss:"0.66745, "val acc: "0.58654
# 2: "val loss:"0.63241, "val acc: "0.58173
# 2: "val loss:"0.65210, "val acc: "0.60096
# 2: "val loss:"0.70532, "val acc: "0.56731
# 2: "val loss:"0.65366, "val acc: "0.57692
# 2: "val loss:"0.68539, "val acc: "0.56731
# 2: "val loss:"0.65816, "val acc: "0.62500
# 2: "val loss:"0.64341, "val acc: "0.62500
# 2: "val loss:"0.69819, "val acc: "0.55288
# 2: "val loss:"0.67427, "val acc: "0.57692
# 2: "val loss:"0.66687, "val acc: "0.57212
# 2: "val loss:"0.69113, "val acc: "0.59135
# 2: "val loss:"0.61998, "val acc: "0.61538
# 2: "val loss:"0.66691, "val acc: "0.58654
# 2: "val loss:"0.65100, "val acc: "0.59615
# 2: "val loss:"0.67862, "val acc: "0.56731
# 2: "val loss:"0.65623, "val acc: "0.58173
# 2: "val loss:"0.63681, "val acc: "0.60577
# 2: "val loss:"0.62659, "val acc: "0.63942
# 2: "val loss:"0.67519, "val acc: "0.58173
# 2: "val loss:"0.66032, "val acc: "0.58173
# 2: "val loss:"0.71438, "val acc: "0.55769
# 2: "val loss:"0.66486, "val acc: "0.60096
# 2: "val loss:"0.62977, "val acc: "0.58654
# 2: "val loss:"0.66649, "val acc: "0.58173
# 2: "val loss:"0.61030, "val acc: "0.62019
# 2: "val loss:"0.59000, "val acc: "0.64904
# 2: "val loss:"0.62624, "val acc: "0.62981
# 2: "val loss:"0.63515, "val acc: "0.58173
# 2: "val loss:"0.65700, "val acc: "0.57212
# 2: "val loss:"0.66377, "val acc: "0.56250
# 2: "val loss:"0.61856, "val acc: "0.59615
# 2: "val loss:"0.67391, "val acc: "0.56250
# 2: "val loss:"0.64080, "val acc: "0.59135
# 2: "val loss:"0.63309, "val acc: "0.60096
# 2: "val loss:"0.63608, "val acc: "0.60096
# 2: "val loss:"0.67786, "val acc: "0.58654
# 2: "val loss:"0.63519, "val acc: "0.58173
# 2: "val loss:"0.68863, "val acc: "0.54808
# 2: "val loss:"0.64232, "val acc: "0.62981
# 2: "val loss:"0.64621, "val acc: "0.62500
# 2: "val loss:"0.67859, "val acc: "0.55769
# 2: "val loss:"0.64162, "val acc: "0.60096
# 2: "val loss:"0.63811, "val acc: "0.57692
# 2: "val loss:"0.66668, "val acc: "0.61538
# 2: "val loss:"0.63333, "val acc: "0.61538
# 2: "val loss:"0.64593, "val acc: "0.59135
# 2: "val loss:"0.66032, "val acc: "0.61058
# 2: "val loss:"0.65131, "val acc: "0.57212
# 2: "val loss:"0.68369, "val acc: "0.60096
# 2: "val loss:"0.63435, "val acc: "0.61538
# 2: "val loss:"0.61718, "val acc: "0.62019
# 2: "val loss:"0.66239, "val acc: "0.62500
# 2: "val loss:"0.70982, "val acc: "0.56250
# 2: "val loss:"0.66071, "val acc: "0.61538
# 2: "val loss:"0.61845, "val acc: "0.59135
# 2: "val loss:"0.61581, "val acc: "0.60096
# 2: "val loss:"0.65102, "val acc: "0.60096
# 2: "val loss:"0.65882, "val acc: "0.63942
# 2: "val loss:"0.66702, "val acc: "0.58173
# 2: "val loss:"0.63726, "val acc: "0.60577
# 2: "val loss:"0.63571, "val acc: "0.58173
# 2: "val loss:"0.66773, "val acc: "0.63462
# 2: "val loss:"0.62948, "val acc: "0.62981
# 2: "val loss:"0.63863, "val acc: "0.59615
# 2: "val loss:"0.66387, "val acc: "0.60577
# 2: "val loss:"0.65520, "val acc: "0.62500
# 2: "val loss:"0.64594, "val acc: "0.61058
# 2: "val loss:"0.65259, "val acc: "0.60577
# 2: "val loss:"0.61785, "val acc: "0.64423
# 2: "val loss:"0.65119, "val acc: "0.55288
# 2: "val loss:"0.63392, "val acc: "0.63462
# 2: "val loss:"0.61255, "val acc: "0.63942
# 2: "val loss:"0.62762, "val acc: "0.60577
# 2: "val loss:"0.64528, "val acc: "0.61058
# 2: "val loss:"0.68625, "val acc: "0.60096
# 2: "val loss:"0.66753, "val acc: "0.58654
# 2: "val loss:"0.59936, "val acc: "0.61538
# 2: "val loss:"0.66988, "val acc: "0.61058
# 2: "val loss:"0.61963, "val acc: "0.63462
# 2: "val loss:"0.69377, "val acc: "0.59615
# 2: "val loss:"0.64161, "val acc: "0.58173
# 2: "val loss:"0.64453, "val acc: "0.60577
# 2: "val loss:"0.70327, "val acc: "0.54808
# 2: "val loss:"0.64561, "val acc: "0.60577
# 2: "val loss:"0.62316, "val acc: "0.62500
# 2: "val loss:"0.68645, "val acc: "0.59615
# 2: "val loss:"0.65247, "val acc: "0.58173
# 2: "val loss:"0.68618, "val acc: "0.62019
# 2: "val loss:"0.68304, "val acc: "0.59135
# 2: "val loss:"0.65216, "val acc: "0.62019
# 2: "val loss:"0.66089, "val acc: "0.60577
# 2: "val loss:"0.65805, "val acc: "0.59615
# 2: "val loss:"0.66994, "val acc: "0.55769
# 2: "val loss:"0.60646, "val acc: "0.62019
# 2: "val loss:"0.67875, "val acc: "0.57212
# 2: "val loss:"0.61444, "val acc: "0.61538
# 2: "val loss:"0.65523, "val acc: "0.61538
# 2: "val loss:"0.64150, "val acc: "0.57692
# 2: "val loss:"0.63665, "val acc: "0.58173
# 2: "val loss:"0.66815, "val acc: "0.59615
# 2: "val loss:"0.66022, "val acc: "0.59135
# 2: "val loss:"0.61194, "val acc: "0.62019
# 2: "val loss:"0.66914, "val acc: "0.58654
# 2: "val loss:"0.67894, "val acc: "0.58173
# 2: "val loss:"0.66055, "val acc: "0.60577
# 2: "val loss:"0.66900, "val acc: "0.61058
# 2: "val loss:"0.67411, "val acc: "0.57212
# 2: "val loss:"0.63484, "val acc: "0.62981
# 2: "val loss:"0.63615, "val acc: "0.60577
# 2: "val loss:"0.64428, "val acc: "0.61058
# 2: "val loss:"0.65528, "val acc: "0.60577
# 2: "val loss:"0.61832, "val acc: "0.62019
# 2: "val loss:"0.68298, "val acc: "0.57212
# 2: "val loss:"0.66370, "val acc: "0.60577
# 3: "train loss:"0.66432, "train acc: "0.52644
# 3: "train loss:"0.64802, "train acc: "0.50721
# 3: "train loss:"0.65843, "train acc: "0.53606
# 3: "train loss:"0.66856, "train acc: "0.56010
# 3: "train loss:"0.68196, "train acc: "0.53846
# 3: "train loss:"0.67047, "train acc: "0.52644
# 3: "train loss:"0.69579, "train acc: "0.53846
# 3: "train loss:"0.66654, "train acc: "0.53125
# 3: "train loss:"0.64999, "train acc: "0.55288
# 3: "train loss:"0.69025, "train acc: "0.51683
# 3: "train loss:"0.68273, "train acc: "0.53125
# 3: "train loss:"0.67987, "train acc: "0.55288
# 3: "train loss:"0.67219, "train acc: "0.57452
# 3: "train loss:"0.67714, "train acc: "0.56250
# 3: "train loss:"0.65603, "train acc: "0.54567
# 3: "train loss:"0.65897, "train acc: "0.59615
# ...
# 12: "train loss:"0.53266, "train acc: "0.75240
# 12: "train loss:"0.49959, "train acc: "0.72356
# 12: "train loss:"0.66271, "train acc: "0.58894
# 12: "train loss:"0.52544, "train acc: "0.48077
# 12: "train loss:"0.61290, "train acc: "0.53606
# 12: "train loss:"0.64724, "train acc: "0.56250
# 12: "train loss:"0.62156, "train acc: "0.54808
# 12: "train loss:"0.61125, "train acc: "0.57452
# 12: "train loss:"0.53397, "train acc: "0.60337
# 12: "train loss:"0.51755, "train acc: "0.72596
# 12: "train loss:"0.49495, "train acc: "0.77404
# 12: "train loss:"0.63148, "train acc: "0.57452
# 12: "train loss:"0.54282, "train acc: "0.77163
# 12: "train loss:"0.62907, "train acc: "0.52644
# 12: "train loss:"0.54270, "train acc: "0.52163
# 12: "train loss:"0.63748, "train acc: "0.55769
# 12: "train loss:"0.65286, "train acc: "0.57692
# 12: "train loss:"0.64832, "train acc: "0.56731
# 12: "train loss:"0.45512, "train acc: "0.80288
# 12: "train loss:"0.47777, "train acc: "0.52885
# 12: "train loss:"0.61734, "train acc: "0.64423
# 12: "train loss:"0.52307, "train acc: "0.74760
# 12: "train loss:"0.55275, "train acc: "0.73317
# 12: "train loss:"0.63872, "train acc: "0.63702
# 12: "train loss:"0.44910, "train acc: "0.79087
# 12: "train loss:"0.50928, "train acc: "0.51923
# 12: "train loss:"0.63534, "train acc: "0.47356
# 12: "train loss:"0.65664, "train acc: "0.60337
# 12: "train loss:"0.54257, "train acc: "0.52885
# 12: "train loss:"0.64242, "train acc: "0.68990
# 12: "train loss:"0.49132, "train acc: "0.80288
# 12: "train loss:"0.67327, "train acc: "0.57933
# 12: "train loss:"0.62535, "train acc: "0.57212
# 12: "train loss:"0.66062, "train acc: "0.51683
# 12: "train loss:"0.53281, "train acc: "0.57452
# 12: "val loss:"0.49742, "val acc: "0.72115
# 12: "val loss:"0.42260, "val acc: "0.79808
# 12: "val loss:"0.52484, "val acc: "0.72596
# 12: "val loss:"0.48878, "val acc: "0.75000
# 12: "val loss:"0.51318, "val acc: "0.76923
# 12: "val loss:"0.43213, "val acc: "0.79327
# 12: "val loss:"0.43216, "val acc: "0.78846
# 12: "val loss:"0.43726, "val acc: "0.76923
# 12: "val loss:"0.54030, "val acc: "0.74519
# 12: "val loss:"0.41712, "val acc: "0.79327
# 12: "val loss:"0.47321, "val acc: "0.79808
# 12: "val loss:"0.39891, "val acc: "0.79327
# 12: "val loss:"0.48110, "val acc: "0.76923
# 12: "val loss:"0.43532, "val acc: "0.80288
# 12: "val loss:"0.39749, "val acc: "0.79327
# 12: "val loss:"0.52852, "val acc: "0.75962
# 12: "val loss:"0.51006, "val acc: "0.76923
# 12: "val loss:"0.41263, "val acc: "0.80288
# 12: "val loss:"0.44144, "val acc: "0.79327
# 12: "val loss:"0.42282, "val acc: "0.81731
# 12: "val loss:"0.49130, "val acc: "0.76923
# 12: "val loss:"0.51012, "val acc: "0.77404
# 12: "val loss:"0.47069, "val acc: "0.77885
# 12: "val loss:"0.40622, "val acc: "0.81250
# 12: "val loss:"0.51759, "val acc: "0.75000
# 12: "val loss:"0.43330, "val acc: "0.76442
# 12: "val loss:"0.44282, "val acc: "0.78365
# 12: "val loss:"0.40496, "val acc: "0.82212
# 12: "val loss:"0.48652, "val acc: "0.76442
# 12: "val loss:"0.48640, "val acc: "0.75962
# 12: "val loss:"0.47217, "val acc: "0.75962
# 12: "val loss:"0.48715, "val acc: "0.76923
# 12: "val loss:"0.43512, "val acc: "0.79808
# 12: "val loss:"0.40213, "val acc: "0.82692
# 12: "val loss:"0.50185, "val acc: "0.74038
# 12: "val loss:"0.47384, "val acc: "0.79327
# 12: "val loss:"0.36807, "val acc: "0.81250
# 12: "val loss:"0.39350, "val acc: "0.81250
# 12: "val loss:"0.57352, "val acc: "0.75000
# 12: "val loss:"0.42499, "val acc: "0.78365
# 12: "val loss:"0.50774, "val acc: "0.73558
# 12: "val loss:"0.41876, "val acc: "0.80288
# 12: "val loss:"0.44606, "val acc: "0.75962
# 12: "val loss:"0.42060, "val acc: "0.81731
# 12: "val loss:"0.43108, "val acc: "0.80769
# 12: "val loss:"0.43924, "val acc: "0.77885
# 12: "val loss:"0.44292, "val acc: "0.76442
# 12: "val loss:"0.42272, "val acc: "0.81731
# 12: "val loss:"0.55066, "val acc: "0.73558
# 12: "val loss:"0.41824, "val acc: "0.80769
# 12: "val loss:"0.44184, "val acc: "0.77885
# 12: "val loss:"0.46952, "val acc: "0.75962
# 12: "val loss:"0.46789, "val acc: "0.77404
# 12: "val loss:"0.43270, "val acc: "0.78365
# 12: "val loss:"0.46502, "val acc: "0.77404
# 12: "val loss:"0.38976, "val acc: "0.79808
# 12: "val loss:"0.52022, "val acc: "0.76442
# 12: "val loss:"0.47098, "val acc: "0.79808
# 12: "val loss:"0.44170, "val acc: "0.79327
# 12: "val loss:"0.46211, "val acc: "0.76442
# 12: "val loss:"0.40330, "val acc: "0.82212
# 12: "val loss:"0.39463, "val acc: "0.82212
# 12: "val loss:"0.52637, "val acc: "0.77404
# 12: "val loss:"0.51808, "val acc: "0.75000
# 12: "val loss:"0.44735, "val acc: "0.78365
# 12: "val loss:"0.47178, "val acc: "0.76442
# 12: "val loss:"0.47856, "val acc: "0.75962
# 12: "val loss:"0.38026, "val acc: "0.79327
# 12: "val loss:"0.49035, "val acc: "0.75000
# 12: "val loss:"0.46072, "val acc: "0.73077
# 12: "val loss:"0.38336, "val acc: "0.81731
# 12: "val loss:"0.43625, "val acc: "0.77885
# 12: "val loss:"0.40780, "val acc: "0.81731
# 12: "val loss:"0.42955, "val acc: "0.78365
# 12: "val loss:"0.45504, "val acc: "0.76442
# 12: "val loss:"0.55108, "val acc: "0.75481
# 12: "val loss:"0.35336, "val acc: "0.83173
# 12: "val loss:"0.45285, "val acc: "0.77885
# 12: "val loss:"0.54423, "val acc: "0.72596
# 12: "val loss:"0.43895, "val acc: "0.81731
# 12: "val loss:"0.42756, "val acc: "0.78846
# 12: "val loss:"0.46057, "val acc: "0.75962
# 12: "val loss:"0.39859, "val acc: "0.79808
# 12: "val loss:"0.45357, "val acc: "0.79808
# 12: "val loss:"0.46036, "val acc: "0.82212
# 12: "val loss:"0.43349, "val acc: "0.78846
# 12: "val loss:"0.45029, "val acc: "0.76442
# 12: "val loss:"0.45672, "val acc: "0.78365
# 12: "val loss:"0.41484, "val acc: "0.80288
# 12: "val loss:"0.46902, "val acc: "0.77885
# 12: "val loss:"0.46855, "val acc: "0.76923
# 12: "val loss:"0.55527, "val acc: "0.72596
# 12: "val loss:"0.44078, "val acc: "0.75481
# 12: "val loss:"0.49168, "val acc: "0.74038
# 12: "val loss:"0.44522, "val acc: "0.79808
# 12: "val loss:"0.44726, "val acc: "0.78365
# 12: "val loss:"0.48553, "val acc: "0.77404
# 12: "val loss:"0.56125, "val acc: "0.70192
# 12: "val loss:"0.41673, "val acc: "0.82692
# 12: "val loss:"0.38315, "val acc: "0.81250
# 12: "val loss:"0.46034, "val acc: "0.78365
# 12: "val loss:"0.54628, "val acc: "0.74038
# 12: "val loss:"0.50848, "val acc: "0.76442
# 12: "val loss:"0.48889, "val acc: "0.73077
# 12: "val loss:"0.40365, "val acc: "0.80769
# 12: "val loss:"0.44734, "val acc: "0.78365
# 12: "val loss:"0.43017, "val acc: "0.73558
# 12: "val loss:"0.39877, "val acc: "0.79808
# 12: "val loss:"0.49398, "val acc: "0.74519
# 12: "val loss:"0.41969, "val acc: "0.81250
# 12: "val loss:"0.45788, "val acc: "0.77885
# 12: "val loss:"0.44627, "val acc: "0.77404
# 12: "val loss:"0.43977, "val acc: "0.78846
# 12: "val loss:"0.50180, "val acc: "0.75000
# 12: "val loss:"0.46238, "val acc: "0.76442
# 12: "val loss:"0.43331, "val acc: "0.79327
# 12: "val loss:"0.46310, "val acc: "0.80288
# 12: "val loss:"0.40028, "val acc: "0.83173
# 12: "val loss:"0.43504, "val acc: "0.77885
# 12: "val loss:"0.52701, "val acc: "0.74038
# 12: "val loss:"0.47787, "val acc: "0.76923
# 12: "val loss:"0.46235, "val acc: "0.78846
# 12: "val loss:"0.42004, "val acc: "0.78846
# 12: "val loss:"0.47546, "val acc: "0.74519
# 12: "val loss:"0.45150, "val acc: "0.78846
# 13: "train loss:"0.64709, "train acc: "0.53606
# 13: "train loss:"0.52310, "train acc: "0.49760
# 13: "train loss:"0.64774, "train acc: "0.66106
# 13: "train loss:"0.51013, "train acc: "0.51442
# 13: "train loss:"0.58882, "train acc: "0.71394
# 13: "train loss:"0.65885, "train acc: "0.56010
# 13: "train loss:"0.65368, "train acc: "0.53125
# 13: "train loss:"0.64312, "train acc: "0.62981
# 13: "train loss:"0.51224, "train acc: "0.80048
# 13: "train loss:"0.63591, "train acc: "0.57212
# 13: "train loss:"0.66577, "train acc: "0.57212
# 13: "train loss:"0.66468, "train acc: "0.62740
# 13: "train loss:"0.50948, "train acc: "0.55048
# 13: "train loss:"0.61178, "train acc: "0.55769
# 13: "train loss:"0.61927, "train acc: "0.59375
# 13: "train loss:"0.62600, "train acc: "0.65625
# 13: "train loss:"0.59599, "train acc: "0.72596
# 13: "train loss:"0.51935, "train acc: "0.75000
# 13: "train loss:"0.65173, "train acc: "0.62740
# 13: "train loss:"0.59045, "train acc: "0.75000
# 13: "train loss:"0.54260, "train acc: "0.73317
# 13: "train loss:"0.60119, "train acc: "0.74279
# 13: "train loss:"0.46397, "train acc: "0.55288
# 13: "train loss:"0.57064, "train acc: "0.75721
# 13: "train loss:"0.65212, "train acc: "0.55048
# 13: "train loss:"0.58993, "train acc: "0.72596
# 13: "train loss:"0.49921, "train acc: "0.78846
# 13: "train loss:"0.51561, "train acc: "0.75481
# 13: "train loss:"0.54048, "train acc: "0.48558
# 13: "train loss:"0.51220, "train acc: "0.48558
# 13: "train loss:"0.52511, "train acc: "0.76923
# 13: "train loss:"0.46620, "train acc: "0.47356
# 13: "train loss:"0.59230, "train acc: "0.75240
# 13: "train loss:"0.60976, "train acc: "0.70913
# 13: "train loss:"0.65167, "train acc: "0.62260
# 13: "train loss:"0.58651, "train acc: "0.71635
# 13: "train loss:"0.62536, "train acc: "0.60577
# 13: "train loss:"0.60376, "train acc: "0.70433
# 13: "train loss:"0.63874, "train acc: "0.53846
# 13: "train loss:"0.48630, "train acc: "0.51442
# 13: "train loss:"0.59884, "train acc: "0.50481
# 13: "train loss:"0.50375, "train acc: "0.75481
# 13: "train loss:"0.55051, "train acc: "0.57452
# 13: "train loss:"0.65285, "train acc: "0.54327
# 13: "train loss:"0.57488, "train acc: "0.53125
# 13: "train loss:"0.54767, "train acc: "0.57692
# 13: "train loss:"0.58628, "train acc: "0.53365
# 13: "train loss:"0.51726, "train acc: "0.52644
# 13: "train loss:"0.60111, "train acc: "0.49279
# 13: "train loss:"0.50493, "train acc: "0.79327
# 13: "train loss:"0.65380, "train acc: "0.63702
# 13: "train loss:"0.60750, "train acc: "0.52885
# 13: "train loss:"0.61147, "train acc: "0.51202
# 13: "train loss:"0.58340, "train acc: "0.56250
# 13: "train loss:"0.64477, "train acc: "0.47837
# 13: "train loss:"0.52699, "train acc: "0.79087
# 13: "train loss:"0.55500, "train acc: "0.77163
# 13: "train loss:"0.63482, "train acc: "0.64663
# 13: "train loss:"0.57006, "train acc: "0.76442
# 13: "train loss:"0.49994, "train acc: "0.77644
# 13: "train loss:"0.65855, "train acc: "0.56731
# 13: "train loss:"0.57803, "train acc: "0.49279
# 13: "train loss:"0.42832, "train acc: "0.81971
# 13: "train loss:"0.54769, "train acc: "0.50481
# 13: "train loss:"0.42734, "train acc: "0.79087
# 13: "train loss:"0.65369, "train acc: "0.58413
# 13: "train loss:"0.54067, "train acc: "0.76442
# 13: "train loss:"0.63075, "train acc: "0.62981
# 13: "train loss:"0.64156, "train acc: "0.67308
# 13: "train loss:"0.48870, "train acc: "0.81250
# 13: "train loss:"0.52968, "train acc: "0.53846
# 13: "train loss:"0.49003, "train acc: "0.80288
# 13: "train loss:"0.66042, "train acc: "0.53846
# 13: "train loss:"0.63333, "train acc: "0.68029
# 13: "train loss:"0.62397, "train acc: "0.71875
# 13: "train loss:"0.65672, "train acc: "0.65144
# 13: "train loss:"0.58766, "train acc: "0.72596
# 13: "train loss:"0.64812, "train acc: "0.56250
# 13: "train loss:"0.58254, "train acc: "0.74279
# 13: "train loss:"0.52268, "train acc: "0.76202
# 13: "train loss:"0.61587, "train acc: "0.64904
# 13: "train loss:"0.60227, "train acc: "0.46154
# 13: "train loss:"0.56672, "train acc: "0.75240
# 13: "train loss:"0.66318, "train acc: "0.58654
# 13: "train loss:"0.51459, "train acc: "0.51442
# 13: "train loss:"0.64070, "train acc: "0.62260
# 13: "train loss:"0.57292, "train acc: "0.54808
# 13: "train loss:"0.52662, "train acc: "0.78365
# 13: "train loss:"0.62318, "train acc: "0.68750
# 13: "train loss:"0.57642, "train acc: "0.73077
# 13: "train loss:"0.49192, "train acc: "0.48558
# 13: "train loss:"0.64360, "train acc: "0.54808
# 13: "train loss:"0.64323, "train acc: "0.57692
# 13: "train loss:"0.64066, "train acc: "0.67308
# 13: "train loss:"0.56760, "train acc: "0.51923
# 13: "train loss:"0.55034, "train acc: "0.74760
# 13: "train loss:"0.53652, "train acc: "0.52644
# 13: "train loss:"0.47069, "train acc: "0.81250
# 13: "train loss:"0.61842, "train acc: "0.71875
# 13: "train loss:"0.60226, "train acc: "0.53606
# 13: "train loss:"0.59384, "train acc: "0.50962
# 13: "train loss:"0.45817, "train acc: "0.81010
# 13: "train loss:"0.62242, "train acc: "0.69712
# 13: "train loss:"0.51547, "train acc: "0.75481
# 13: "train loss:"0.68099, "train acc: "0.57933
# 13: "train loss:"0.58985, "train acc: "0.51202
# 13: "train loss:"0.57516, "train acc: "0.72596
# 13: "train loss:"0.62859, "train acc: "0.63221
# 13: "train loss:"0.51336, "train acc: "0.79567
# 13: "train loss:"0.55692, "train acc: "0.74760
# 13: "train loss:"0.57502, "train acc: "0.54327
# 13: "train loss:"0.61070, "train acc: "0.54087
# 13: "train loss:"0.61167, "train acc: "0.72115
# 13: "train loss:"0.55816, "train acc: "0.52163
# 13: "train loss:"0.46555, "train acc: "0.80048
# 13: "train loss:"0.63842, "train acc: "0.68750
# 13: "train loss:"0.52341, "train acc: "0.52404
# 13: "train loss:"0.64352, "train acc: "0.61298
# 13: "train loss:"0.66172, "train acc: "0.57452
# 13: "train loss:"0.45041, "train acc: "0.52163
# 13: "train loss:"0.63381, "train acc: "0.58413
# 13: "train loss:"0.55109, "train acc: "0.74760
# 13: "train loss:"0.50532, "train acc: "0.76923
# 13: "train loss:"0.66881, "train acc: "0.57933
# 13: "train loss:"0.64438, "train acc: "0.66346
# 13: "train loss:"0.48874, "train acc: "0.76683
# 13: "train loss:"0.57748, "train acc: "0.55529
# 13: "train loss:"0.52506, "train acc: "0.53125
# 13: "train loss:"0.63586, "train acc: "0.62019
# 13: "train loss:"0.48827, "train acc: "0.77885
# 13: "train loss:"0.48055, "train acc: "0.51442
# 13: "train loss:"0.59317, "train acc: "0.72837
# 13: "train loss:"0.50615, "train acc: "0.78606
# 13: "train loss:"0.57155, "train acc: "0.48798
# 13: "train loss:"0.55693, "train acc: "0.53846
# 13: "train loss:"0.52645, "train acc: "0.49519
# 13: "train loss:"0.64009, "train acc: "0.61058
# 13: "train loss:"0.51633, "train acc: "0.75240
# 13: "train loss:"0.58409, "train acc: "0.77163
# 13: "train loss:"0.63768, "train acc: "0.68750
# 13: "train loss:"0.61517, "train acc: "0.53846
# 13: "train loss:"0.65431, "train acc: "0.58173
# 13: "train loss:"0.47298, "train acc: "0.76683
# 13: "train loss:"0.59109, "train acc: "0.70913
# 13: "train loss:"0.54064, "train acc: "0.76442
# 13: "train loss:"0.58749, "train acc: "0.59375
# 13: "train loss:"0.48554, "train acc: "0.53846
# 13: "train loss:"0.51145, "train acc: "0.53606
# 13: "train loss:"0.62238, "train acc: "0.50481
# 13: "train loss:"0.60172, "train acc: "0.71635
# 13: "train loss:"0.47903, "train acc: "0.56250
# 13: "train loss:"0.50596, "train acc: "0.48558
# 13: "train loss:"0.62005, "train acc: "0.51923
# 13: "train loss:"0.61740, "train acc: "0.69471
# 13: "train loss:"0.66002, "train acc: "0.55769
# 13: "train loss:"0.65690, "train acc: "0.59856
# 13: "train loss:"0.67266, "train acc: "0.51923
# 13: "train loss:"0.65278, "train acc: "0.64663
# 13: "train loss:"0.60475, "train acc: "0.75481
# 13: "train loss:"0.65151, "train acc: "0.66106
# 13: "train loss:"0.63814, "train acc: "0.66106
# 13: "train loss:"0.65762, "train acc: "0.58894
# 13: "train loss:"0.54773, "train acc: "0.49519
# 13: "train loss:"0.54068, "train acc: "0.79087
# 13: "train loss:"0.50276, "train acc: "0.79327
# 13: "train loss:"0.60074, "train acc: "0.54327
# 13: "train loss:"0.63917, "train acc: "0.59375
# 13: "train loss:"0.56889, "train acc: "0.72837
# 13: "train loss:"0.50813, "train acc: "0.51683
# 13: "train loss:"0.57717, "train acc: "0.75240
# 13: "train loss:"0.59313, "train acc: "0.56010
# 13: "train loss:"0.61062, "train acc: "0.53125
# 13: "train loss:"0.62237, "train acc: "0.48558
# 13: "train loss:"0.46398, "train acc: "0.76683
# 13: "train loss:"0.54401, "train acc: "0.74760
# 13: "train loss:"0.56505, "train acc: "0.49519
# 13: "train loss:"0.61950, "train acc: "0.63221
# 13: "train loss:"0.61232, "train acc: "0.56971
# 13: "train loss:"0.61950, "train acc: "0.55288
# 13: "train loss:"0.56881, "train acc: "0.49519
# 13: "train loss:"0.43796, "train acc: "0.81490
# 13: "train loss:"0.58564, "train acc: "0.73558
# 13: "train loss:"0.58528, "train acc: "0.73077
# 13: "train loss:"0.53326, "train acc: "0.55529
# 13: "train loss:"0.47350, "train acc: "0.78606
# 13: "train loss:"0.60626, "train acc: "0.54567
# 13: "train loss:"0.59870, "train acc: "0.52404
# 13: "train loss:"0.61540, "train acc: "0.71154
# 13: "train loss:"0.62633, "train acc: "0.61538
# 13: "train loss:"0.48971, "train acc: "0.75481
# 13: "train loss:"0.45185, "train acc: "0.54808

# %%
MODEL = "06012 eff0"

torch.save(model.state_dict(), f'{path}_{MODEL}.pth')

# %%
import matplotlib.pyplot as plt


plt.plot(train_acc_list,color='#e35f62', label='Train Acc')

plt.xlabel('Acc')
plt.ylabel('Epoch')
plt.title('Train')
plt.show()

# %%
plt.plot(valid_acc_list,color='green', label='Valid Acc')
plt.xlabel('Acc')
plt.ylabel('Epoch')
plt.title('Valid')
plt.show()

# %% [markdown]
# # 기록
# 1번
# lr=1e-3
#
# 1.   optimizer : Adam
# 2.   scheduler : CosineAnnealingLR
# 3.   criterition:MultiLabelSoftMarginLoss
#
#
# ```
# 9: "val loss:"0.57146, "val acc: "0.67067
# 9: "val loss:"0.56269, "val acc: "0.67788
# 9: "val loss:"0.56572, "val acc: "0.67308
# 9: "val loss:"0.57164, "val acc: "0.66827
# 9: "val loss:"0.54050, "val acc: "0.73077
# 9: "val loss:"0.56166, "val acc: "0.66106
# 9: "val loss:"0.53295, "val acc: "0.68990
# 9: "val loss:"0.55628, "val acc: "0.68990
# 9: "val loss:"0.52732, "val acc: "0.71394
# ```
#
# 2번
# 1번과 같지만 모델이 efficientnet_b5 훨씬 효능이 좋다.
#
# ```
# 8: "val loss:"0.35732, "val acc: "0.83654
# 8: "val loss:"0.40119, "val acc: "0.81250
# 8: "val loss:"0.44620, "val acc: "0.77885
# 8: "val loss:"0.38490, "val acc: "0.83173
# 8: "val loss:"0.45323, "val acc: "0.81250
# 8: "val loss:"0.48173, "val acc: "0.81731
# 8: "val loss:"0.41693, "val acc: "0.81250
# 8: "val loss:"0.36138, "val acc: "0.85577
# 8: "val loss:"0.32753, "val acc: "0.85096
# 8: "val loss:"0.39352, "val acc: "0.84615
# 8: "val loss:"0.41519, "val acc: "0.81731
# 8: "val loss:"0.39349, "val acc: "0.80769
# 8: "val loss:"0.40276, "val acc: "0.82692
# 8: "val loss:"0.40279, "val acc: "0.80288
# 8: "val loss:"0.38277, "val acc: "0.82692
# 8: "val loss:"0.35343, "val acc: "0.85577
# ```
